# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

#Pipeline creation
from sklearn.pipeline import Pipeline

#Data processing modules
from sklearn.model_selection import train_test_split
from sklearn.model_selection import KFold
from sklearn.preprocessing import MinMaxScaler
from sklearn.model_selection import cross_val_score, cross_val_predict

#importing various Ml classifiers
from sklearn.tree import DecisionTreeClassifier
from xgboost import XGBClassifier
from sklearn.ensemble import AdaBoostClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.svm import SVC
from sklearn.neighbors import KNeighborsClassifier
from sklearn.naive_bayes import GaussianNB

#Importing Metric modules
from sklearn.metrics import accuracy_score, confusion_matrix, classification_report, roc_auc_score, f1_score

# %%
# Extracted Features path
healthy_features_path = 'featuresvalues_new.csv'
tumor_features_path = 'tumorfeaturesvalues_new.csv'

# %%
# Reading the healthy pancreas features
data = pd.read_csv(healthy_features_path)
X_healthy = data.iloc[:, :-1]
y_healthy = data.iloc[:, -1]

# %%
# Reading the tumor pancreas features
data_tumor = pd.read_csv(tumor_features_path)
X_tumor = data_tumor.iloc[:, :-1]
y_tumor = data_tumor.iloc[:, -1]

# %%
# data_tumor

# %%
y_healthy.shape
# Out:
# (79,)

# %%
# Concat Features
z=y_tumor.values.reshape(281,1)
h = y_healthy.values.reshape(79,1)
modified_array = np.vstack((z, h))
y = modified_array.reshape(1,360)

# %%
z1=X_tumor.values.reshape(281,107)
h1 = X_healthy.values.reshape(79,107)
modified_array = np.vstack((z1, h1))
X = modified_array.reshape(107,360)

# %%
X =X.reshape(360,107)
y = y.reshape(360,1)

# %%
modified_data = np.hstack((X,y))
df = pd.DataFrame(modified_data)

# %%
# df_shuffled
df
# Out:
#           0    1    2           3           4          5           6    \
# 0    0.774209  0.0  0.0   62.498825   44.687500  59.296875   67.012091
# 1    0.687649  0.0  0.0   81.423081   49.500000  69.265625   88.906661
# 2    0.587004  0.0  0.0   45.459287   22.859375  34.890625   45.023553
# 3    0.687467  0.0  0.0   65.250762   36.609375  55.171875   62.805323
# 4    0.742163  0.0  0.0   66.731863   44.687500  65.484375   71.129800
# ..        ...  ...  ...         ...         ...        ...         ...
# 355  0.236020  0.0  0.0  138.920782   71.875000  38.281250  131.205815
# 356  0.193854  0.0  0.0  162.396489   70.312500  26.367188  141.827003
# 357  0.335641  0.0  0.0  100.225046   54.687500  48.828125   88.307389
# 358  0.532818  0.0  0.0   54.400939   34.179688  41.015625   51.563980
# 359  0.184894  0.0  0.0  172.443819  122.812500  29.062500  133.721156
#
#             7            8          9    ...       98        99        100  \
# 0     67.012091  1699.716187  41.225667  ...  0.015991  6.061205  0.142939
# 1     88.906661  2395.702515  46.603172  ...  0.002551  6.455984  0.306062
# 2     45.023553   754.095968  21.371957  ...  0.019730  5.525098  0.255166
# 3     62.805323  1471.019491  36.718732  ...  0.004378  6.009932  0.261595
# 4     71.129800  1790.234782  43.648946  ...  0.018017  5.749565  0.381538
# ..          ...          ...        ...  ...       ...       ...       ...
# 355  131.205815  2650.858561  32.788112  ...  0.002361  7.235649  0.271580
# 356  141.827003  2212.206523  31.481219  ...  0.027410  5.661709  0.243142
# 357   88.307389  1618.226369  33.639606  ...  0.012035  6.291807  0.299544
# 358   51.563980   652.949015  28.985823  ...  0.024009  5.611265  0.248266
# 359  133.721156  1576.831055  31.883750  ...  0.030018  5.640576  0.406452
#
#             101       102       103          104       105        106  107
# 0    796.772754  1.078497  0.008652    41.108638  0.030069   0.687439  1.0
# 1     55.559027  0.106842  0.005106  1100.218702  0.037558  16.107521  1.0
# 2     46.659327  0.577877  0.019061    59.980274  0.049368   1.508778  1.0
# 3     60.821255  0.217363  0.006768   542.147860  0.016580   8.667461  1.0
# 4     10.353508  1.813233  0.004777    93.984282  0.066585   0.363591  1.0
# ..          ...       ...       ...          ...       ...        ...  ...
# 355  257.247524  0.050817  0.005500  1250.957739  0.054629  19.374934  0.0
# 356  131.112058  2.948380  0.003997    73.166907  0.056923   0.501311  0.0
# 357   35.919704  0.329676  0.007996   423.064167  0.035987   4.055273  0.0
# 358   48.664024  0.268894  0.027179    92.863090  0.062765   3.732317  0.0
# 359    9.481230  1.729093  0.004740   185.259795  0.068346   0.938922  0.0
#
# [360 rows x 108 columns]

# %%
#Pipeline Creation
#Pipeline contains a MinMaxScaler and a classifier

def create_pipeline(classifier):
    steps = list()
    steps.append(("scaler",MinMaxScaler()))
    steps.append(("classifier",classifier))
    pipeline = Pipeline(steps=steps)
    return pipeline

# %%
# 5 fold CV evaluation

def calculate_metrics(pipeline,X,y):
    kfold = KFold(n_splits=5, shuffle=True, random_state=42)

    # Accuracy
    scores_accuracy = cross_val_score(pipeline, X, y, cv=kfold,scoring="accuracy")

    # Print the cross-validation scores
    print("Printing Accuracy scores: ", scores_accuracy)
    print("Mean Accuracy: ", round(np.mean(scores_accuracy),5),'\n')


    # Precision
    scores_precision = cross_val_score(pipeline, X, y, cv=kfold,scoring="precision")

    # Print the cross-validation scores
    print("Printing Precision scores: ", scores_precision)
    print("Mean Precision: ", round(np.mean(scores_precision),5),'\n')

    # ROC-AUC
    scores_roc_auc = cross_val_score(pipeline, X, y, cv=kfold,scoring="roc_auc")

    # Print the cross-validation scores
    print("Printing ROC-AUC scores: ", scores_roc_auc)
    print("Mean ROC-AUC: ", round(np.mean(scores_roc_auc),5),'\n')

    # Recall
    scores_recall = cross_val_score(pipeline, X, y, cv=kfold,scoring="recall")

    # Print the cross-validation scores
    print("Printing Recall scores: ", scores_recall)
    print("Mean Recall: ", round(np.mean(scores_recall),5),'\n')


    # F1-score
    scores_f1 = cross_val_score(pipeline, X, y, cv=kfold,scoring="f1")

    # Print the cross-validation scores
    print("Printing F1 scores: ", scores_f1)
    print("Mean F1: ", round(np.mean(scores_f1),5),'\n')

    return (round(np.mean(scores_accuracy),5),round(np.mean(scores_precision),5),round(np.mean(scores_roc_auc),5),round(np.mean(scores_recall),5),round(np.mean(scores_f1),5))

# %%
# Decision Tree
accuracy_list = []
precision_list = []
recall_list = []
roc_auc_list = []
f1_score_list = []

iterations = 10

for it in range(1,iterations+1):
    print(f"Printing values for iteration {it}\n")
    df_shuffled = df.sample(frac=1) # Shuffling the DataFrame 

    # Extracting values from the shuffled DataFrame in form of NumPy array
    X1= df_shuffled.iloc[:, :-1].values
    y1 = df_shuffled.iloc[:,-1].values

    decision_tree = DecisionTreeClassifier(criterion = "gini",random_state=42)
    pipeline_decision_tree = create_pipeline(decision_tree)
    acc, precision, roc_auc, recall, f1_score = calculate_metrics(pipeline_decision_tree,X1,y1)
    accuracy_list.append(acc)
    precision_list.append(precision)
    roc_auc_list.append(roc_auc)
    recall_list.append(recall)
    f1_score_list.append(f1_score)
# Out:
# Printing values for iteration 1
#
# Printing Accuracy scores:  [0.97222222 0.98611111 0.97222222 0.95833333 0.97222222]
# Mean Accuracy:  0.97222
#
# Printing Precision scores:  [0.96491228 1.         1.         0.96226415 1.        ]
# Mean Precision:  0.98544
#
# Printing ROC-AUC scores:  [0.94117647 0.99152542 0.98305085 0.94038462 0.98214286]
# Mean ROC-AUC:  0.96766
#
# Printing Recall scores:  [1.         0.98305085 0.96610169 0.98076923 0.96428571]
# Mean Recall:  0.97884
#
# Printing F1 scores:  [0.98214286 0.99145299 0.98275862 0.97142857 0.98181818]
# Mean F1:  0.98192
#
# Printing values for iteration 2
#
# Printing Accuracy scores:  [0.94444444 0.97222222 0.95833333 0.97222222 0.94444444]
# Mean Accuracy:  0.95833
#
# Printing Precision scores:  [0.93103448 1.         0.98076923 1.         0.98214286]
# Mean Precision:  0.97879
#
# Printing ROC-AUC scores:  [0.88888889 0.98181818 0.95481629 0.98360656 0.93842365]
# Mean ROC-AUC:  0.94951
#
# Printing Recall scores:  [1.         0.96363636 0.96226415 0.96721311 0.94827586]
# Mean Recall:  0.96828
#
# Printing F1 scores:  [0.96428571 0.98148148 0.97142857 0.98333333 0.96491228]
# Mean F1:  0.97309
#
# Printing values for iteration 3
#
# Printing Accuracy scores:  [0.97222222 0.95833333 0.97222222 0.93055556 0.94444444]
# Mean Accuracy:  0.95556
#
# Printing Precision scores:  [0.96428571 0.98387097 0.98214286 0.97727273 0.96721311]
# Mean Precision:  0.97496
#
# Printing ROC-AUC scores:  [0.94444444 0.92857143 0.95982143 0.93744681 0.89269747]
# Mean ROC-AUC:  0.9326
#
# Printing Recall scores:  [1.         0.96825397 0.98214286 0.91489362 0.96721311]
# Mean Recall:  0.9665
#
# Printing F1 scores:  [0.98181818 0.976      0.98214286 0.94505495 0.96721311]
# Mean F1:  0.97045
#
# Printing values for iteration 4
#
# Printing Accuracy scores:  [0.98611111 1.         0.94444444 0.95833333 0.97222222]
# Mean Accuracy:  0.97222
#
# Printing Precision scores:  [1.         1.         0.94827586 0.97959184 0.98333333]
# Mean Precision:  0.98224
#
# Printing ROC-AUC scores:  [0.99090909 1.         0.89732143 0.95727273 0.95      ]
# Mean ROC-AUC:  0.9591
#
# Printing Recall scores:  [0.98181818 1.         0.98214286 0.96       0.98333333]
# Mean Recall:  0.98146
#
# Printing F1 scores:  [0.99082569 1.         0.96491228 0.96969697 0.98333333]
# Mean F1:  0.98175
#
# Printing values for iteration 5
#
# Printing Accuracy scores:  [0.98611111 0.94444444 0.94444444 0.97222222 0.95833333]
# Mean Accuracy:  0.96111
#
# Printing Precision scores:  [1.         0.96363636 0.96428571 0.98333333 0.96551724]
# Mean Precision:  0.97535
#
# Printing ROC-AUC scores:  [0.99056604 0.92299465 0.91964286 0.95       0.9245614 ]
# Mean ROC-AUC:  0.94155
#
# Printing Recall scores:  [0.98113208 0.96363636 0.96428571 0.98333333 0.98245614]
# Mean Recall:  0.97497
#
# Printing F1 scores:  [0.99047619 0.96363636 0.96428571 0.98333333 0.97391304]
# Mean F1:  0.97513
#
# Printing values for iteration 6
#
# Printing Accuracy scores:  [0.94444444 0.93055556 0.98611111 0.98611111 0.98611111]
# Mean Accuracy:  0.96667
#
# Printing Precision scores:  [0.98275862 0.98148148 0.98214286 0.98214286 0.98181818]
# Mean Precision:  0.98207
#
# Printing ROC-AUC scores:  [0.93333333 0.93157895 0.97058824 0.97058824 0.97222222]
# Mean ROC-AUC:  0.95566
#
# Printing Recall scores:  [0.95       0.92982456 1.         1.         1.        ]
# Mean Recall:  0.97596
#
# Printing F1 scores:  [0.96610169 0.95495495 0.99099099 0.99099099 0.99082569]
# Mean F1:  0.97877
#
# Printing values for iteration 7
#
# Printing Accuracy scores:  [0.95833333 0.95833333 0.94444444 0.94444444 0.95833333]
# Mean Accuracy:  0.95278
#
# Printing Precision scores:  [0.98076923 1.         0.96428571 0.98181818 0.98275862]
# Mean Precision:  0.98193
#
# Printing ROC-AUC scores:  [0.95481629 0.97321429 0.91964286 0.94035088 0.94458931]
# Mean ROC-AUC:  0.94652
#
# Printing Recall scores:  [0.96226415 0.94642857 0.96428571 0.94736842 0.96610169]
# Mean Recall:  0.95729
#
# Printing F1 scores:  [0.97142857 0.97247706 0.96428571 0.96428571 0.97435897]
# Mean F1:  0.96937
#
# Printing values for iteration 8
#
# Printing Accuracy scores:  [0.97222222 0.97222222 0.98611111 0.97222222 0.98611111]
# Mean Accuracy:  0.97778
#
# Printing Precision scores:  [0.98214286 0.96363636 0.98275862 0.98245614 1.        ]
# Mean Precision:  0.9822
#
# Printing ROC-AUC scores:  [0.95982143 0.94736842 0.96666667 0.95789474 0.99137931]
# Mean ROC-AUC:  0.96463
#
# Printing Recall scores:  [0.98214286 1.         1.         0.98245614 0.98275862]
# Mean Recall:  0.98947
#
# Printing F1 scores:  [0.98214286 0.98148148 0.99130435 0.98245614 0.99130435]
# Mean F1:  0.98574
#
# Printing values for iteration 9
#
# Printing Accuracy scores:  [0.95833333 0.98611111 0.98611111 0.95833333 0.98611111]
# Mean Accuracy:  0.975
#
# Printing Precision scores:  [0.94827586 1.         0.98360656 0.97959184 1.        ]
# Mean Precision:  0.98229
#
# Printing ROC-AUC scores:  [0.91176471 0.99122807 0.95833333 0.95727273 0.99152542]
# Mean ROC-AUC:  0.96202
#
# Printing Recall scores:  [1.         0.98245614 1.         0.96       0.98305085]
# Mean Recall:  0.9851
#
# Printing F1 scores:  [0.97345133 0.99115044 0.99173554 0.96969697 0.99145299]
# Mean F1:  0.9835
#
# Printing values for iteration 10
#
# Printing Accuracy scores:  [0.97222222 0.98611111 0.95833333 0.97222222 0.95833333]
# Mean Accuracy:  0.96944
#
# Printing Precision scores:  [1.         0.98305085 0.98360656 0.96       0.98148148]
# Mean Precision:  0.98163
#
# Printing ROC-AUC scores:  [0.98275862 0.96428571 0.93387097 0.95833333 0.95240642]
# Mean ROC-AUC:  0.95833
#
# Printing Recall scores:  [0.96551724 1.         0.96774194 1.         0.96363636]
# Mean Recall:  0.97938
#
# Printing F1 scores:  [0.98245614 0.99145299 0.97560976 0.97959184 0.97247706]
# Mean F1:  0.98032

# %%
print("Printing values for 10 iterations Decision Tree")
# Calculate the mean and std accuracy
mean_accuracy = sum(accuracy_list) / len(accuracy_list)
std_accuracy = np.std(accuracy_list)

# Report the mean accuracy up to 4 decimal points
print(f"Mean Accuracy: {mean_accuracy : .4f}")
print(f"Std Accuracy: {std_accuracy : .4f}")

# Calculate the mean and std precision
mean_precision = sum(precision_list) / len(precision_list)
std_precision = np.std(precision_list)
# Report the mean precision up to 4 decimal points

print(f"Mean Precision: {mean_precision : .4f}")
print(f"Std Precision: {std_precision : .4f}")

# Calculate the mean and std recall
mean_recall = sum(recall_list) / len(recall_list)
std_recall = np.std(recall_list)
# Report the mean recall up to 4 decimal points

print(f"Mean Recall: {mean_recall : .4f}")
print(f"Std Recall: {std_recall : .4f}")

# Calculate the mean and std roc_auc
mean_roc_auc = sum(roc_auc_list) / len(roc_auc_list)
std_roc_auc = np.std(roc_auc_list)
# Report the mean roc_auc up to 4 decimal points

print(f"Mean ROC-AUC: {mean_roc_auc : .4f}")
print(f"Std ROC-AUC: {std_roc_auc : .4f}")

# Calculate the mean and std f1_score
mean_f1_score = sum(f1_score_list) / len(f1_score_list)
std_f1_score = np.std(f1_score_list)
# Report the mean f1-score up to 4 decimal points

print(f"Mean F1-Score: {mean_f1_score : .4f}")
print(f"Std F1-Score: {std_f1_score : .4f}")
# Out:
# Printing values for 10 iterations Decision Tree
# Mean Accuracy:  0.9661
# Std Accuracy:  0.0082
# Mean Precision:  0.9807
# Std Precision:  0.0031
# Mean Recall:  0.9757
# Std Recall:  0.0090
# Mean ROC-AUC:  0.9538
# Std ROC-AUC:  0.0105
# Mean F1-Score:  0.9780
# Std F1-Score:  0.0054

# %%
# AdaBoost
accuracy_list = []
precision_list = []
recall_list = []
roc_auc_list = []
f1_score_list = []

iterations = 10

for it in range(1,iterations+1):
    print(f"Printing values for iteration {it}\n")
    df_shuffled = df.sample(frac=1) # Shuffling the DataFrame 

    # Extracting values from the shuffled DataFrame in form of NumPy array
    X1= df_shuffled.iloc[:, :-1].values
    y1 = df_shuffled.iloc[:,-1].values

    adaboost = AdaBoostClassifier(n_estimators=50, random_state=42)
    pipeline_decision_tree = create_pipeline(adaboost)
    acc, precision, roc_auc, recall, f1_score = calculate_metrics(pipeline_decision_tree,X1,y1)
    accuracy_list.append(acc)
    precision_list.append(precision)
    roc_auc_list.append(roc_auc)
    recall_list.append(recall)
    f1_score_list.append(f1_score)
# Out:
# Printing values for iteration 1
#
# Printing Accuracy scores:  [0.98611111 0.98611111 0.97222222 0.97222222 1.        ]
# Mean Accuracy:  0.98333
#
# Printing Precision scores:  [0.98181818 1.         0.98076923 0.98461538 1.        ]
# Mean Precision:  0.98944
#
# Printing ROC-AUC scores:  [0.96604938 0.99766082 0.99615385 0.98681319 1.        ]
# Mean ROC-AUC:  0.98934
#
# Printing Recall scores:  [1.         0.98245614 0.98076923 0.98461538 1.        ]
# Mean Recall:  0.98957
#
# Printing F1 scores:  [0.99082569 0.99115044 0.98076923 0.98461538 1.        ]
# Mean F1:  0.98947
#
# Printing values for iteration 2
#
# Printing Accuracy scores:  [0.98611111 0.97222222 0.95833333 0.95833333 0.97222222]
# Mean Accuracy:  0.96944
#
# Printing Precision scores:  [1.         0.98387097 0.96       0.94915254 0.98214286]
# Mean Precision:  0.97503
#
# Printing ROC-AUC scores:  [1.         0.98870968 0.99556344 0.96540179 0.99888393]
# Mean ROC-AUC:  0.98971
#
# Printing Recall scores:  [0.98275862 0.98387097 0.97959184 1.         0.98214286]
# Mean Recall:  0.98567
#
# Printing F1 scores:  [0.99130435 0.98387097 0.96969697 0.97391304 0.98214286]
# Mean F1:  0.98019
#
# Printing values for iteration 3
#
# Printing Accuracy scores:  [0.97222222 1.         1.         0.97222222 0.97222222]
# Mean Accuracy:  0.98333
#
# Printing Precision scores:  [0.98275862 1.         1.         0.96666667 0.96491228]
# Mean Precision:  0.98287
#
# Printing ROC-AUC scores:  [0.99137931 1.         1.         0.96182266 0.99893048]
# Mean ROC-AUC:  0.99043
#
# Printing Recall scores:  [0.98275862 1.         1.         1.         1.        ]
# Mean Recall:  0.99655
#
# Printing F1 scores:  [0.98275862 1.         1.         0.98305085 0.98214286]
# Mean F1:  0.98959
#
# Printing values for iteration 4
#
# Printing Accuracy scores:  [1.         0.97222222 0.95833333 0.95833333 0.98611111]
# Mean Accuracy:  0.975
#
# Printing Precision scores:  [1.         0.96721311 0.96428571 0.96363636 0.98333333]
# Mean Precision:  0.97569
#
# Printing ROC-AUC scores:  [1.         0.94263364 0.99786096 0.99588477 0.9934811 ]
# Mean ROC-AUC:  0.98597
#
# Printing Recall scores:  [1.         1.         0.98181818 0.98148148 1.        ]
# Mean Recall:  0.99266
#
# Printing F1 scores:  [1.         0.98333333 0.97297297 0.97247706 0.99159664]
# Mean F1:  0.98408
#
# Printing values for iteration 5
#
# Printing Accuracy scores:  [0.94444444 0.97222222 0.98611111 0.95833333 0.95833333]
# Mean Accuracy:  0.96389
#
# Printing Precision scores:  [0.95833333 0.96610169 0.98412698 0.98181818 0.96610169]
# Mean Precision:  0.9713
#
# Printing ROC-AUC scores:  [0.98958333 0.99883041 0.99032258 0.98995536 0.98399015]
# Mean ROC-AUC:  0.99054
#
# Printing Recall scores:  [0.95833333 1.         1.         0.96428571 0.98275862]
# Mean Recall:  0.98108
#
# Printing F1 scores:  [0.95833333 0.98275862 0.992      0.97297297 0.97435897]
# Mean F1:  0.97608
#
# Printing values for iteration 6
#
# Printing Accuracy scores:  [0.97222222 0.93055556 1.         1.         0.98611111]
# Mean Accuracy:  0.97778
#
# Printing Precision scores:  [0.98181818 0.93442623 1.         1.         0.98214286]
# Mean Precision:  0.97968
#
# Printing ROC-AUC scores:  [0.99893048 0.94334975 1.         1.         1.        ]
# Mean ROC-AUC:  0.98846
#
# Printing Recall scores:  [0.98181818 0.98275862 1.         1.         1.        ]
# Mean Recall:  0.99292
#
# Printing F1 scores:  [0.98181818 0.95798319 1.         1.         0.99099099]
# Mean F1:  0.98616
#
# Printing values for iteration 7
#
# Printing Accuracy scores:  [1.         0.93055556 0.97222222 0.97222222 0.95833333]
# Mean Accuracy:  0.96667
#
# Printing Precision scores:  [1.         0.98113208 0.98360656 0.96078431 0.96610169]
# Mean Precision:  0.97832
#
# Printing ROC-AUC scores:  [1.         0.98995536 0.94336811 0.99733807 0.99753695]
# Mean ROC-AUC:  0.98564
#
# Printing Recall scores:  [1.         0.92857143 0.98360656 1.         0.98275862]
# Mean Recall:  0.97899
#
# Printing F1 scores:  [1.         0.95412844 0.98360656 0.98       0.97435897]
# Mean F1:  0.97842
#
# Printing values for iteration 8
#
# Printing Accuracy scores:  [0.97222222 0.95833333 1.         0.97222222 0.98611111]
# Mean Accuracy:  0.97778
#
# Printing Precision scores:  [1.         0.98275862 1.         0.96491228 0.98275862]
# Mean Precision:  0.98609
#
# Printing ROC-AUC scores:  [0.99608866 0.9934811  1.         0.96791444 0.99415205]
# Mean ROC-AUC:  0.99033
#
# Printing Recall scores:  [0.96610169 0.96610169 1.         1.         1.        ]
# Mean Recall:  0.98644
#
# Printing F1 scores:  [0.98275862 0.97435897 1.         0.98214286 0.99130435]
# Mean F1:  0.98611
#
# Printing values for iteration 9
#
# Printing Accuracy scores:  [0.97222222 1.         0.94444444 0.97222222 0.98611111]
# Mean Accuracy:  0.975
#
# Printing Precision scores:  [0.96428571 1.         0.94642857 0.96721311 0.98181818]
# Mean Precision:  0.97195
#
# Printing ROC-AUC scores:  [0.9840535  1.         0.968107   0.99869622 1.        ]
# Mean ROC-AUC:  0.99017
#
# Printing Recall scores:  [1.         1.         0.98148148 1.         1.        ]
# Mean Recall:  0.9963
#
# Printing F1 scores:  [0.98181818 1.         0.96363636 0.98333333 0.99082569]
# Mean F1:  0.98392
#
# Printing values for iteration 10
#
# Printing Accuracy scores:  [1.         0.95833333 0.97222222 1.         0.98611111]
# Mean Accuracy:  0.98333
#
# Printing Precision scores:  [1.         0.96666667 1.         1.         0.98214286]
# Mean Precision:  0.98976
#
# Printing ROC-AUC scores:  [1.         0.99217731 1.         1.         0.9657754 ]
# Mean ROC-AUC:  0.99159
#
# Printing Recall scores:  [1.         0.98305085 0.96666667 1.         1.        ]
# Mean Recall:  0.98994
#
# Printing F1 scores:  [1.         0.97478992 0.98305085 1.         0.99099099]
# Mean F1:  0.98977

# %%
print("Printing values for 10 iterations AdaBoost")
# Calculate the mean and std accuracy
mean_accuracy = sum(accuracy_list) / len(accuracy_list)
std_accuracy = np.std(accuracy_list)

# Report the mean accuracy up to 4 decimal points
print(f"Mean Accuracy: {mean_accuracy : .4f}")
print(f"Std Accuracy: {std_accuracy : .4f}")

# Calculate the mean and std precision
mean_precision = sum(precision_list) / len(precision_list)
std_precision = np.std(precision_list)
# Report the mean precision up to 4 decimal points

print(f"Mean Precision: {mean_precision : .4f}")
print(f"Std Precision: {std_precision : .4f}")

# Calculate the mean and std recall
mean_recall = sum(recall_list) / len(recall_list)
std_recall = np.std(recall_list)
# Report the mean recall up to 4 decimal points

print(f"Mean Recall: {mean_recall : .4f}")
print(f"Std Recall: {std_recall : .4f}")

# Calculate the mean and std roc_auc
mean_roc_auc = sum(roc_auc_list) / len(roc_auc_list)
std_roc_auc = np.std(roc_auc_list)
# Report the mean roc_auc up to 4 decimal points

print(f"Mean ROC-AUC: {mean_roc_auc : .4f}")
print(f"Std ROC-AUC: {std_roc_auc : .4f}")

# Calculate the mean and std f1_score
mean_f1_score = sum(f1_score_list) / len(f1_score_list)
std_f1_score = np.std(f1_score_list)
# Report the mean f1-score up to 4 decimal points

print(f"Mean F1-Score: {mean_f1_score : .4f}")
print(f"Std F1-Score: {std_f1_score : .4f}")
# Out:
# Printing values for 10 iterations AdaBoost
# Mean Accuracy:  0.9756
# Std Accuracy:  0.0067
# Mean Precision:  0.9800
# Std Precision:  0.0065
# Mean Recall:  0.9890
# Std Recall:  0.0057
# Mean ROC-AUC:  0.9892
# Std ROC-AUC:  0.0019
# Mean F1-Score:  0.9844
# Std F1-Score:  0.0046

# %%
# XGBoost
accuracy_list = []
precision_list = []
recall_list = []
roc_auc_list = []
f1_score_list = []

iterations = 10

for it in range(1,iterations+1):
    print(f"Printing values for iteration {it}\n")
    df_shuffled = df.sample(frac=1) # Shuffling the DataFrame 

    # Extracting values from the shuffled DataFrame in form of NumPy array
    X1= df_shuffled.iloc[:, :-1].values
    y1 = df_shuffled.iloc[:,-1].values

    xgb_classifier = XGBClassifier(n_estimators=100, learning_rate=0.01, random_state=42)
    pipeline_decision_tree = create_pipeline(xgb_classifier)
    acc, precision, roc_auc, recall, f1_score = calculate_metrics(pipeline_decision_tree,X1,y1)
    accuracy_list.append(acc)
    precision_list.append(precision)
    roc_auc_list.append(roc_auc)
    recall_list.append(recall)
    f1_score_list.append(f1_score)
# Out:
# Printing values for iteration 1
#
# Printing Accuracy scores:  [0.97222222 0.94444444 0.97222222 0.98611111 0.97222222]
# Mean Accuracy:  0.96944
#
# Printing Precision scores:  [0.96428571 0.93333333 0.96551724 0.98181818 0.96825397]
# Mean Precision:  0.96264
#
# Printing ROC-AUC scores:  [1.         0.99553571 0.984375   1.         0.94038748]
# Mean ROC-AUC:  0.98406
#
# Printing Recall scores:  [1. 1. 1. 1. 1.]
# Mean Recall:  1.0
#
# Printing F1 scores:  [0.98181818 0.96551724 0.98245614 0.99082569 0.98387097]
# Mean F1:  0.9809
#
# Printing values for iteration 2
#
# Printing Accuracy scores:  [0.95833333 0.98611111 0.98611111 0.95833333 0.97222222]
# Mean Accuracy:  0.97222
#
# Printing Precision scores:  [0.95       0.98333333 0.98245614 0.94642857 0.96551724]
# Mean Precision:  0.96555
#
# Printing ROC-AUC scores:  [0.95380117 0.99608866 0.98883929 0.99503476 0.98883929]
# Mean ROC-AUC:  0.98452
#
# Printing Recall scores:  [1. 1. 1. 1. 1.]
# Mean Recall:  1.0
#
# Printing F1 scores:  [0.97435897 0.99159664 0.99115044 0.97247706 0.98245614]
# Mean F1:  0.98241
#
# Printing values for iteration 3
#
# Printing Accuracy scores:  [1.         0.98611111 0.94444444 0.94444444 0.98611111]
# Mean Accuracy:  0.97222
#
# Printing Precision scores:  [1.         0.98181818 0.93333333 0.92982456 0.98387097]
# Mean Precision:  0.96577
#
# Printing ROC-AUC scores:  [1.         1.         0.94810268 0.99751738 0.93517139]
# Mean ROC-AUC:  0.97616
#
# Printing Recall scores:  [1. 1. 1. 1. 1.]
# Mean Recall:  1.0
#
# Printing F1 scores:  [1.         0.99082569 0.96551724 0.96363636 0.99186992]
# Mean F1:  0.98237
#
# Printing values for iteration 4
#
# Printing Accuracy scores:  [0.97222222 0.97222222 0.95833333 0.98611111 0.98611111]
# Mean Accuracy:  0.975
#
# Printing Precision scores:  [0.96610169 0.96551724 0.94736842 0.98214286 0.98333333]
# Mean Precision:  0.96889
#
# Printing ROC-AUC scores:  [0.98947368 0.99665179 0.96296296 0.99893048 0.99608866]
# Mean ROC-AUC:  0.98882
#
# Printing Recall scores:  [1. 1. 1. 1. 1.]
# Mean Recall:  1.0
#
# Printing F1 scores:  [0.98275862 0.98245614 0.97297297 0.99099099 0.99159664]
# Mean F1:  0.98416
#
# Printing values for iteration 5
#
# Printing Accuracy scores:  [0.94444444 0.97222222 0.97222222 0.98611111 1.        ]
# Mean Accuracy:  0.975
#
# Printing Precision scores:  [0.93220339 0.96428571 0.96428571 0.98333333 1.        ]
# Mean Precision:  0.96882
#
# Printing ROC-AUC scores:  [0.99358289 0.98868313 0.98251029 0.95306389 1.        ]
# Mean ROC-AUC:  0.98357
#
# Printing Recall scores:  [1. 1. 1. 1. 1.]
# Mean Recall:  1.0
#
# Printing F1 scores:  [0.96491228 0.98181818 0.98181818 0.99159664 1.        ]
# Mean F1:  0.98403
#
# Printing values for iteration 6
#
# Printing Accuracy scores:  [0.97222222 1.         1.         0.95833333 0.95833333]
# Mean Accuracy:  0.97778
#
# Printing Precision scores:  [0.96491228 1.         1.         0.94642857 0.94736842]
# Mean Precision:  0.97174
#
# Printing ROC-AUC scores:  [1.         1.         1.         0.9980139  0.95884774]
# Mean ROC-AUC:  0.99137
#
# Printing Recall scores:  [1. 1. 1. 1. 1.]
# Mean Recall:  1.0
#
# Printing F1 scores:  [0.98214286 1.         1.         0.97247706 0.97297297]
# Mean F1:  0.98552
#
# Printing values for iteration 7
#
# Printing Accuracy scores:  [0.95833333 0.95833333 0.98611111 0.97222222 0.98611111]
# Mean Accuracy:  0.97222
#
# Printing Precision scores:  [0.94736842 0.94642857 0.98305085 0.96666667 0.98305085]
# Mean Precision:  0.96531
#
# Printing ROC-AUC scores:  [0.99074074 0.93296922 0.99507389 0.98337438 1.        ]
# Mean ROC-AUC:  0.98043
#
# Printing Recall scores:  [1. 1. 1. 1. 1.]
# Mean Recall:  1.0
#
# Printing F1 scores:  [0.97297297 0.97247706 0.99145299 0.98305085 0.99145299]
# Mean F1:  0.98228
#
# Printing values for iteration 8
#
# Printing Accuracy scores:  [1.         1.         0.93055556 0.97222222 0.97222222]
# Mean Accuracy:  0.975
#
# Printing Precision scores:  [1.         1.         0.921875   0.96491228 0.96363636]
# Mean Precision:  0.97008
#
# Printing ROC-AUC scores:  [1.         1.         0.89569752 0.99572193 0.98808342]
# Mean ROC-AUC:  0.9759
#
# Printing Recall scores:  [1. 1. 1. 1. 1.]
# Mean Recall:  1.0
#
# Printing F1 scores:  [1.         1.         0.95934959 0.98214286 0.98148148]
# Mean F1:  0.98459
#
# Printing values for iteration 9
#
# Printing Accuracy scores:  [0.97222222 0.95833333 0.94444444 1.         0.98611111]
# Mean Accuracy:  0.97222
#
# Printing Precision scores:  [0.96551724 0.94642857 0.92982456 1.         0.98360656]
# Mean Precision:  0.96508
#
# Printing ROC-AUC scores:  [1.         1.         0.95431976 1.         1.        ]
# Mean ROC-AUC:  0.99086
#
# Printing Recall scores:  [1. 1. 1. 1. 1.]
# Mean Recall:  1.0
#
# Printing F1 scores:  [0.98245614 0.97247706 0.96363636 1.         0.99173554]
# Mean F1:  0.98206
#
# Printing values for iteration 10
#
# Printing Accuracy scores:  [0.97222222 0.98611111 0.97222222 0.98611111 0.91666667]
# Mean Accuracy:  0.96667
#
# Printing Precision scores:  [0.98148148 0.98214286 0.96721311 0.98245614 0.93220339]
# Mean Precision:  0.9691
#
# Printing ROC-AUC scores:  [0.99794239 1.         0.98826597 1.         0.94035088]
# Mean ROC-AUC:  0.98531
#
# Printing Recall scores:  [0.98148148 1.         1.         1.         0.96491228]
# Mean Recall:  0.98928
#
# Printing F1 scores:  [0.98148148 0.99099099 0.98333333 0.99115044 0.94827586]
# Mean F1:  0.97905

# %%
print("Printing values for 10 iterations XGBoost")
# Calculate the mean and std accuracy
mean_accuracy = sum(accuracy_list) / len(accuracy_list)
std_accuracy = np.std(accuracy_list)

# Report the mean accuracy up to 4 decimal points
print(f"Mean Accuracy: {mean_accuracy : .4f}")
print(f"Std Accuracy: {std_accuracy : .4f}")

# Calculate the mean and std precision
mean_precision = sum(precision_list) / len(precision_list)
std_precision = np.std(precision_list)
# Report the mean precision up to 4 decimal points

print(f"Mean Precision: {mean_precision : .4f}")
print(f"Std Precision: {std_precision : .4f}")

# Calculate the mean and std recall
mean_recall = sum(recall_list) / len(recall_list)
std_recall = np.std(recall_list)
# Report the mean recall up to 4 decimal points

print(f"Mean Recall: {mean_recall : .4f}")
print(f"Std Recall: {std_recall : .4f}")

# Calculate the mean and std roc_auc
mean_roc_auc = sum(roc_auc_list) / len(roc_auc_list)
std_roc_auc = np.std(roc_auc_list)
# Report the mean roc_auc up to 4 decimal points

print(f"Mean ROC-AUC: {mean_roc_auc : .4f}")
print(f"Std ROC-AUC: {std_roc_auc : .4f}")

# Calculate the mean and std f1_score
mean_f1_score = sum(f1_score_list) / len(f1_score_list)
std_f1_score = np.std(f1_score_list)
# Report the mean f1-score up to 4 decimal points

print(f"Mean F1-Score: {mean_f1_score : .4f}")
print(f"Std F1-Score: {std_f1_score : .4f}")
# Out:
# Printing values for 10 iterations XGBoost
# Mean Accuracy:  0.9728
# Std Accuracy:  0.0030
# Mean Precision:  0.9673
# Std Precision:  0.0027
# Mean Recall:  0.9989
# Std Recall:  0.0032
# Mean ROC-AUC:  0.9841
# Std ROC-AUC:  0.0052
# Mean F1-Score:  0.9827
# Std F1-Score:  0.0018

# %%
# Random Forest
accuracy_list = []
precision_list = []
recall_list = []
roc_auc_list = []
f1_score_list = []

iterations = 10

for it in range(1,iterations+1):
    print(f"Printing values for iteration {it}\n")
    df_shuffled = df.sample(frac=1) # Shuffling the DataFrame 

    # Extracting values from the shuffled DataFrame in form of NumPy array
    X1= df_shuffled.iloc[:, :-1].values
    y1 = df_shuffled.iloc[:,-1].values

    rf_classifier = RandomForestClassifier(n_estimators=100, random_state=42)
    pipeline_decision_tree = create_pipeline(rf_classifier)
    acc, precision, roc_auc, recall, f1_score = calculate_metrics(pipeline_decision_tree,X1,y1)
    accuracy_list.append(acc)
    precision_list.append(precision)
    roc_auc_list.append(roc_auc)
    recall_list.append(recall)
    f1_score_list.append(f1_score)
# Out:
# Printing values for iteration 1
#
# Printing Accuracy scores:  [0.95833333 1.         0.97222222 0.94444444 0.95833333]
# Mean Accuracy:  0.96667
#
# Printing Precision scores:  [0.94230769 1.         1.         0.96721311 0.98113208]
# Mean Precision:  0.97813
#
# Printing ROC-AUC scores:  [0.98890861 1.         0.99876847 0.97168405 0.99691358]
# Mean ROC-AUC:  0.99125
#
# Printing Recall scores:  [1.         1.         0.96551724 0.96721311 0.96296296]
# Mean Recall:  0.97914
#
# Printing F1 scores:  [0.97029703 1.         0.98245614 0.96721311 0.97196262]
# Mean F1:  0.97839
#
# Printing values for iteration 2
#
# Printing Accuracy scores:  [0.95833333 0.97222222 0.93055556 0.98611111 1.        ]
# Mean Accuracy:  0.96944
#
# Printing Precision scores:  [0.96428571 0.96610169 0.96296296 1.         1.        ]
# Mean Precision:  0.97867
#
# Printing ROC-AUC scores:  [0.97860963 0.99181287 0.99037433 1.         1.        ]
# Mean ROC-AUC:  0.99216
#
# Printing Recall scores:  [0.98181818 1.         0.94545455 0.98333333 1.        ]
# Mean Recall:  0.98212
#
# Printing F1 scores:  [0.97297297 0.98275862 0.95412844 0.99159664 1.        ]
# Mean F1:  0.98029
#
# Printing values for iteration 3
#
# Printing Accuracy scores:  [1.         0.97222222 0.97222222 0.97222222 0.94444444]
# Mean Accuracy:  0.97222
#
# Printing Precision scores:  [1.         0.96721311 0.98181818 0.96363636 0.98245614]
# Mean Precision:  0.97902
#
# Printing ROC-AUC scores:  [1.         0.99869622 0.99465241 0.95531281 0.99478488]
# Mean ROC-AUC:  0.98869
#
# Printing Recall scores:  [1.         1.         0.98181818 1.         0.94915254]
# Mean Recall:  0.98619
#
# Printing F1 scores:  [1.         0.98333333 0.98181818 0.98148148 0.96551724]
# Mean F1:  0.98243
#
# Printing values for iteration 4
#
# Printing Accuracy scores:  [0.98611111 0.98611111 0.93055556 0.97222222 0.97222222]
# Mean Accuracy:  0.96944
#
# Printing Precision scores:  [0.98214286 1.         0.94642857 0.96363636 1.        ]
# Mean Precision:  0.97844
#
# Printing ROC-AUC scores:  [0.99786096 1.         0.94705882 0.99602781 1.        ]
# Mean ROC-AUC:  0.98819
#
# Printing Recall scores:  [1.         0.98245614 0.96363636 1.         0.96721311]
# Mean Recall:  0.98266
#
# Printing F1 scores:  [0.99099099 0.99115044 0.95495495 0.98148148 0.98333333]
# Mean F1:  0.98038
#
# Printing values for iteration 5
#
# Printing Accuracy scores:  [1.         0.94444444 0.97222222 0.98611111 0.95833333]
# Mean Accuracy:  0.97222
#
# Printing Precision scores:  [1.         0.98113208 0.96296296 0.98214286 0.96666667]
# Mean Precision:  0.97858
#
# Printing ROC-AUC scores:  [1.         0.99572193 0.95480769 0.99786096 0.99543677]
# Mean ROC-AUC:  0.98877
#
# Printing Recall scores:  [1.         0.94545455 1.         1.         0.98305085]
# Mean Recall:  0.9857
#
# Printing F1 scores:  [1.         0.96296296 0.98113208 0.99099099 0.97478992]
# Mean F1:  0.98198
#
# Printing values for iteration 6
#
# Printing Accuracy scores:  [0.98611111 0.95833333 0.97222222 0.97222222 0.97222222]
# Mean Accuracy:  0.97222
#
# Printing Precision scores:  [1.         0.96491228 1.         0.96825397 0.96610169]
# Mean Precision:  0.97985
#
# Printing ROC-AUC scores:  [0.99914894 0.96651786 1.         0.99329359 0.99415205]
# Mean ROC-AUC:  0.99062
#
# Printing Recall scores:  [0.9787234  0.98214286 0.96666667 1.         1.        ]
# Mean Recall:  0.98551
#
# Printing F1 scores:  [0.98924731 0.97345133 0.98305085 0.98387097 0.98275862]
# Mean F1:  0.98248
#
# Printing values for iteration 7
#
# Printing Accuracy scores:  [0.93055556 0.97222222 1.         0.95833333 0.98611111]
# Mean Accuracy:  0.96944
#
# Printing Precision scores:  [0.94444444 1.         1.         0.96551724 0.98275862]
# Mean Precision:  0.97854
#
# Printing ROC-AUC scores:  [0.94885799 0.99893048 1.         0.99298246 1.        ]
# Mean ROC-AUC:  0.98815
#
# Printing Recall scores:  [0.96226415 0.96363636 1.         0.98245614 1.        ]
# Mean Recall:  0.98167
#
# Printing F1 scores:  [0.95327103 0.98148148 1.         0.97391304 0.99130435]
# Mean F1:  0.97999
#
# Printing values for iteration 8
#
# Printing Accuracy scores:  [0.94444444 0.98611111 0.95833333 0.98611111 0.98611111]
# Mean Accuracy:  0.97222
#
# Printing Precision scores:  [0.96363636 0.98148148 0.96610169 1.         0.98245614]
# Mean Precision:  0.97874
#
# Printing ROC-AUC scores:  [0.95294118 0.9980139  0.99568966 1.         1.        ]
# Mean ROC-AUC:  0.98933
#
# Printing Recall scores:  [0.96363636 1.         0.98275862 0.98305085 1.        ]
# Mean Recall:  0.98589
#
# Printing F1 scores:  [0.96363636 0.99065421 0.97435897 0.99145299 0.99115044]
# Mean F1:  0.98225
#
# Printing values for iteration 9
#
# Printing Accuracy scores:  [0.97222222 0.98611111 0.94444444 0.95833333 0.98611111]
# Mean Accuracy:  0.96944
#
# Printing Precision scores:  [0.96428571 1.         1.         0.94827586 0.98181818]
# Mean Precision:  0.97888
#
# Printing ROC-AUC scores:  [1.         1.         0.99776786 0.95508021 1.        ]
# Mean ROC-AUC:  0.99057
#
# Printing Recall scores:  [1.         0.98387097 0.92857143 1.         1.        ]
# Mean Recall:  0.98249
#
# Printing F1 scores:  [0.98181818 0.99186992 0.96296296 0.97345133 0.99082569]
# Mean F1:  0.98019
#
# Printing values for iteration 10
#
# Printing Accuracy scores:  [0.98611111 0.95833333 0.97222222 0.97222222 0.95833333]
# Mean Accuracy:  0.96944
#
# Printing Precision scores:  [0.984375   0.98305085 0.98039216 0.96551724 0.98      ]
# Mean Precision:  0.97867
#
# Printing ROC-AUC scores:  [0.95061728 0.99236111 0.99719888 0.99330357 0.99626517]
# Mean ROC-AUC:  0.98595
#
# Printing Recall scores:  [1.         0.96666667 0.98039216 1.         0.96078431]
# Mean Recall:  0.98157
#
# Printing F1 scores:  [0.99212598 0.97478992 0.98039216 0.98245614 0.97029703]
# Mean F1:  0.98001

# %%
print("Printing values for 10 iterations Random Forest")
# Calculate the mean and std accuracy
mean_accuracy = sum(accuracy_list) / len(accuracy_list)
std_accuracy = np.std(accuracy_list)

# Report the mean accuracy up to 4 decimal points
print(f"Mean Accuracy: {mean_accuracy : .4f}")
print(f"Std Accuracy: {std_accuracy : .4f}")

# Calculate the mean and std precision
mean_precision = sum(precision_list) / len(precision_list)
std_precision = np.std(precision_list)
# Report the mean precision up to 4 decimal points

print(f"Mean Precision: {mean_precision : .4f}")
print(f"Std Precision: {std_precision : .4f}")

# Calculate the mean and std recall
mean_recall = sum(recall_list) / len(recall_list)
std_recall = np.std(recall_list)
# Report the mean recall up to 4 decimal points

print(f"Mean Recall: {mean_recall : .4f}")
print(f"Std Recall: {std_recall : .4f}")

# Calculate the mean and std roc_auc
mean_roc_auc = sum(roc_auc_list) / len(roc_auc_list)
std_roc_auc = np.std(roc_auc_list)
# Report the mean roc_auc up to 4 decimal points

print(f"Mean ROC-AUC: {mean_roc_auc : .4f}")
print(f"Std ROC-AUC: {std_roc_auc : .4f}")

# Calculate the mean and std f1_score
mean_f1_score = sum(f1_score_list) / len(f1_score_list)
std_f1_score = np.std(f1_score_list)
# Report the mean f1-score up to 4 decimal points

print(f"Mean F1-Score: {mean_f1_score : .4f}")
print(f"Std F1-Score: {std_f1_score : .4f}")
# Out:
# Printing values for 10 iterations Random Forest
# Mean Accuracy:  0.9703
# Std Accuracy:  0.0018
# Mean Precision:  0.9788
# Std Precision:  0.0004
# Mean Recall:  0.9833
# Std Recall:  0.0023
# Mean ROC-AUC:  0.9894
# Std ROC-AUC:  0.0017
# Mean F1-Score:  0.9808
# Std F1-Score:  0.0013

# %%
# SVC
accuracy_list = []
precision_list = []
recall_list = []
roc_auc_list = []
f1_score_list = []

iterations = 10

for it in range(1,iterations+1):
    print(f"Printing values for iteration {it}\n")
    df_shuffled = df.sample(frac=1) # Shuffling the DataFrame 

    # Extracting values from the shuffled DataFrame in form of NumPy array
    X1= df_shuffled.iloc[:, :-1].values
    y1 = df_shuffled.iloc[:,-1].values

    svc_classifier = SVC(kernel='rbf', C=1.0, gamma='scale')
    pipeline_decision_tree = create_pipeline(svc_classifier)
    acc, precision, roc_auc, recall, f1_score = calculate_metrics(pipeline_decision_tree,X1,y1)
    accuracy_list.append(acc)
    precision_list.append(precision)
    roc_auc_list.append(roc_auc)
    recall_list.append(recall)
    f1_score_list.append(f1_score)
# Out:
# Printing values for iteration 1
#
# Printing Accuracy scores:  [0.98611111 0.98611111 0.97222222 0.97222222 0.97222222]
# Mean Accuracy:  0.97778
#
# Printing Precision scores:  [1.         0.98214286 0.96551724 0.96610169 0.96721311]
# Mean Precision:  0.97619
#
# Printing ROC-AUC scores:  [1.         0.98716578 0.99776786 1.         0.94132986]
# Mean ROC-AUC:  0.98525
#
# Printing Recall scores:  [0.98148148 1.         1.         1.         1.        ]
# Mean Recall:  0.9963
#
# Printing F1 scores:  [0.99065421 0.99099099 0.98245614 0.98275862 0.98333333]
# Mean F1:  0.98604
#
# Printing values for iteration 2
#
# Printing Accuracy scores:  [0.98611111 0.98611111 0.98611111 0.95833333 0.97222222]
# Mean Accuracy:  0.97778
#
# Printing Precision scores:  [0.98148148 0.98333333 0.98333333 0.96296296 0.96610169]
# Mean Precision:  0.97544
#
# Printing ROC-AUC scores:  [0.9980139  1.         1.         0.98609732 0.94502924]
# Mean ROC-AUC:  0.98583
#
# Printing Recall scores:  [1.         1.         1.         0.98113208 1.        ]
# Mean Recall:  0.99623
#
# Printing F1 scores:  [0.99065421 0.99159664 0.99159664 0.97196262 0.98275862]
# Mean F1:  0.98571
#
# Printing values for iteration 3
#
# Printing Accuracy scores:  [0.98611111 0.98611111 0.98611111 1.         0.93055556]
# Mean Accuracy:  0.97778
#
# Printing Precision scores:  [0.98039216 0.984375   0.98333333 1.         0.93548387]
# Mean Precision:  0.97672
#
# Printing ROC-AUC scores:  [1.         1.         1.         1.         0.91134289]
# Mean ROC-AUC:  0.98227
#
# Printing Recall scores:  [1.         1.         1.         1.         0.98305085]
# Mean Recall:  0.99661
#
# Printing F1 scores:  [0.99009901 0.99212598 0.99159664 1.         0.95867769]
# Mean F1:  0.9865
#
# Printing values for iteration 4
#
# Printing Accuracy scores:  [0.98611111 0.95833333 1.         1.         0.95833333]
# Mean Accuracy:  0.98056
#
# Printing Precision scores:  [0.98181818 0.94736842 1.         1.         0.96610169]
# Mean Precision:  0.97906
#
# Printing ROC-AUC scores:  [0.99588477 0.95987654 1.         1.         0.98891626]
# Mean ROC-AUC:  0.98894
#
# Printing Recall scores:  [1.         1.         1.         1.         0.98275862]
# Mean Recall:  0.99655
#
# Printing F1 scores:  [0.99082569 0.97297297 1.         1.         0.97435897]
# Mean F1:  0.98763
#
# Printing values for iteration 5
#
# Printing Accuracy scores:  [0.97222222 0.95833333 1.         0.97222222 0.97222222]
# Mean Accuracy:  0.975
#
# Printing Precision scores:  [0.96721311 0.94444444 1.         0.96721311 0.98214286]
# Mean Precision:  0.9722
#
# Printing ROC-AUC scores:  [0.98565841 1.         1.         1.         0.9609375 ]
# Mean ROC-AUC:  0.98932
#
# Printing Recall scores:  [1.         1.         1.         1.         0.98214286]
# Mean Recall:  0.99643
#
# Printing F1 scores:  [0.98333333 0.97142857 1.         0.98333333 0.98214286]
# Mean F1:  0.98405
#
# Printing values for iteration 6
#
# Printing Accuracy scores:  [1.         0.95833333 0.95833333 0.97222222 1.        ]
# Mean Accuracy:  0.97778
#
# Printing Precision scores:  [1.         0.95918367 0.94339623 0.96363636 1.        ]
# Mean Precision:  0.97324
#
# Printing ROC-AUC scores:  [1.         0.99479167 0.97       0.99900695 1.        ]
# Mean ROC-AUC:  0.99276
#
# Printing Recall scores:  [1.         0.97916667 1.         1.         1.        ]
# Mean Recall:  0.99583
#
# Printing F1 scores:  [1.         0.96907216 0.97087379 0.98148148 1.        ]
# Mean F1:  0.98429
#
# Printing values for iteration 7
#
# Printing Accuracy scores:  [0.98611111 0.98611111 0.95833333 0.98611111 0.97222222]
# Mean Accuracy:  0.97778
#
# Printing Precision scores:  [0.98360656 0.98214286 0.94736842 0.98387097 0.98039216]
# Mean Precision:  0.97548
#
# Printing ROC-AUC scores:  [1.         0.9657754  0.98868313 1.         0.99626517]
# Mean ROC-AUC:  0.99014
#
# Printing Recall scores:  [1.         1.         1.         1.         0.98039216]
# Mean Recall:  0.99608
#
# Printing F1 scores:  [0.99173554 0.99099099 0.97297297 0.99186992 0.98039216]
# Mean F1:  0.98559
#
# Printing values for iteration 8
#
# Printing Accuracy scores:  [0.98611111 0.95833333 0.98611111 0.98611111 0.95833333]
# Mean Accuracy:  0.975
#
# Printing Precision scores:  [0.98360656 0.94642857 0.98387097 0.98076923 0.96491228]
# Mean Precision:  0.97192
#
# Printing ROC-AUC scores:  [1.         0.99702085 0.94932936 0.99439776 0.99107143]
# Mean ROC-AUC:  0.98636
#
# Printing Recall scores:  [1.         1.         1.         1.         0.98214286]
# Mean Recall:  0.99643
#
# Printing F1 scores:  [0.99173554 0.97247706 0.99186992 0.99029126 0.97345133]
# Mean F1:  0.98397
#
# Printing values for iteration 9
#
# Printing Accuracy scores:  [0.95833333 0.98611111 0.98611111 0.95833333 0.98611111]
# Mean Accuracy:  0.975
#
# Printing Precision scores:  [0.95       0.98181818 0.98181818 0.96551724 0.98333333]
# Mean Precision:  0.9725
#
# Printing ROC-AUC scores:  [0.99766082 1.         1.         0.9871345  0.94393742]
# Mean ROC-AUC:  0.98575
#
# Printing Recall scores:  [1.         1.         1.         0.98245614 1.        ]
# Mean Recall:  0.99649
#
# Printing F1 scores:  [0.97435897 0.99082569 0.99082569 0.97391304 0.99159664]
# Mean F1:  0.9843
#
# Printing values for iteration 10
#
# Printing Accuracy scores:  [0.97222222 0.98611111 0.97222222 1.         0.95833333]
# Mean Accuracy:  0.97778
#
# Printing Precision scores:  [0.96226415 0.98305085 0.96428571 1.         0.96551724]
# Mean Precision:  0.97502
#
# Printing ROC-AUC scores:  [0.9719888  1.         0.98662551 1.         0.98596491]
# Mean ROC-AUC:  0.98892
#
# Printing Recall scores:  [1.         1.         1.         1.         0.98245614]
# Mean Recall:  0.99649
#
# Printing F1 scores:  [0.98076923 0.99145299 0.98181818 1.         0.97391304]
# Mean F1:  0.98559

# %%
print("Printing values for 10 iterations SVC")
# Calculate the mean and std accuracy
mean_accuracy = sum(accuracy_list) / len(accuracy_list)
std_accuracy = np.std(accuracy_list)

# Report the mean accuracy up to 4 decimal points
print(f"Mean Accuracy: {mean_accuracy : .4f}")
print(f"Std Accuracy: {std_accuracy : .4f}")

# Calculate the mean and std precision
mean_precision = sum(precision_list) / len(precision_list)
std_precision = np.std(precision_list)
# Report the mean precision up to 4 decimal points

print(f"Mean Precision: {mean_precision : .4f}")
print(f"Std Precision: {std_precision : .4f}")

# Calculate the mean and std recall
mean_recall = sum(recall_list) / len(recall_list)
std_recall = np.std(recall_list)
# Report the mean recall up to 4 decimal points

print(f"Mean Recall: {mean_recall : .4f}")
print(f"Std Recall: {std_recall : .4f}")

# Calculate the mean and std roc_auc
mean_roc_auc = sum(roc_auc_list) / len(roc_auc_list)
std_roc_auc = np.std(roc_auc_list)
# Report the mean roc_auc up to 4 decimal points

print(f"Mean ROC-AUC: {mean_roc_auc : .4f}")
print(f"Std ROC-AUC: {std_roc_auc : .4f}")

# Calculate the mean and std f1_score
mean_f1_score = sum(f1_score_list) / len(f1_score_list)
std_f1_score = np.std(f1_score_list)
# Report the mean f1-score up to 4 decimal points

print(f"Mean F1-Score: {mean_f1_score : .4f}")
print(f"Std F1-Score: {std_f1_score : .4f}")
# Out:
# Printing values for 10 iterations SVC
# Mean Accuracy:  0.9772
# Std Accuracy:  0.0017
# Mean Precision:  0.9748
# Std Precision:  0.0022
# Mean Recall:  0.9963
# Std Recall:  0.0002
# Mean ROC-AUC:  0.9876
# Std ROC-AUC:  0.0029
# Mean F1-Score:  0.9854
# Std F1-Score:  0.0011

# %%
# KNN
accuracy_list = []
precision_list = []
recall_list = []
roc_auc_list = []
f1_score_list = []

iterations = 10

for it in range(1,iterations+1):
    print(f"Printing values for iteration {it}\n")
    df_shuffled = df.sample(frac=1) # Shuffling the DataFrame 

    # Extracting values from the shuffled DataFrame in form of NumPy array
    X1= df_shuffled.iloc[:, :-1].values
    y1 = df_shuffled.iloc[:,-1].values

    knn = KNeighborsClassifier(n_neighbors=6)
    pipeline_decision_tree = create_pipeline(knn)
    acc, precision, roc_auc, recall, f1_score = calculate_metrics(pipeline_decision_tree,X1,y1)
    accuracy_list.append(acc)
    precision_list.append(precision)
    roc_auc_list.append(roc_auc)
    recall_list.append(recall)
    f1_score_list.append(f1_score)
# Out:
# Printing values for iteration 1
#
# Printing Accuracy scores:  [0.875      0.97222222 0.94444444 0.94444444 0.97222222]
# Mean Accuracy:  0.94167
#
# Printing Precision scores:  [0.85714286 0.98461538 0.96491228 0.98076923 0.96551724]
# Mean Precision:  0.95059
#
# Printing ROC-AUC scores:  [0.94631766 0.92087912 0.99005848 0.99176955 0.99888393]
# Mean ROC-AUC:  0.96958
#
# Printing Recall scores:  [0.97959184 0.98461538 0.96491228 0.94444444 1.        ]
# Mean Recall:  0.97471
#
# Printing F1 scores:  [0.91428571 0.98461538 0.96491228 0.96226415 0.98245614]
# Mean F1:  0.96171
#
# Printing values for iteration 2
#
# Printing Accuracy scores:  [0.95833333 0.94444444 0.98611111 0.95833333 0.94444444]
# Mean Accuracy:  0.95833
#
# Printing Precision scores:  [0.96428571 0.96610169 0.98275862 0.94827586 0.96363636]
# Mean Precision:  0.96501
#
# Printing ROC-AUC scores:  [0.96417112 0.94980443 0.9994152  0.96791444 0.96042781]
# Mean ROC-AUC:  0.96835
#
# Printing Recall scores:  [0.98181818 0.96610169 1.         1.         0.96363636]
# Mean Recall:  0.98231
#
# Printing F1 scores:  [0.97297297 0.96610169 0.99130435 0.97345133 0.96363636]
# Mean F1:  0.97349
#
# Printing values for iteration 3
#
# Printing Accuracy scores:  [0.95833333 0.97222222 0.95833333 0.95833333 0.97222222]
# Mean Accuracy:  0.96389
#
# Printing Precision scores:  [0.98148148 0.98305085 0.94642857 0.96363636 0.98333333]
# Mean Precision:  0.97159
#
# Printing ROC-AUC scores:  [0.99411765 0.95371578 0.94240318 0.99537037 0.95416667]
# Mean ROC-AUC:  0.96795
#
# Printing Recall scores:  [0.96363636 0.98305085 1.         0.98148148 0.98333333]
# Mean Recall:  0.9823
#
# Printing F1 scores:  [0.97247706 0.98305085 0.97247706 0.97247706 0.98333333]
# Mean F1:  0.97676
#
# Printing values for iteration 4
#
# Printing Accuracy scores:  [0.93055556 0.95833333 0.97222222 0.98611111 0.97222222]
# Mean Accuracy:  0.96389
#
# Printing Precision scores:  [0.93220339 0.94230769 0.98245614 1.         1.        ]
# Mean Precision:  0.97139
#
# Printing ROC-AUC scores:  [0.89732143 0.97648625 0.99122807 0.99930556 0.99869622]
# Mean ROC-AUC:  0.97261
#
# Printing Recall scores:  [0.98214286 1.         0.98245614 0.98333333 0.96610169]
# Mean Recall:  0.98281
#
# Printing F1 scores:  [0.95652174 0.97029703 0.98245614 0.99159664 0.98275862]
# Mean F1:  0.97673
#
# Printing values for iteration 5
#
# Printing Accuracy scores:  [0.98611111 0.94444444 0.97222222 0.98611111 0.94444444]
# Mean Accuracy:  0.96667
#
# Printing Precision scores:  [0.98076923 0.96491228 0.98275862 0.98181818 0.95238095]
# Mean Precision:  0.97253
#
# Printing ROC-AUC scores:  [0.97432306 0.98654971 0.95258621 1.         0.94262295]
# Mean ROC-AUC:  0.97122
#
# Printing Recall scores:  [1.         0.96491228 0.98275862 1.         0.98360656]
# Mean Recall:  0.98626
#
# Printing F1 scores:  [0.99029126 0.96491228 0.98275862 0.99082569 0.96774194]
# Mean F1:  0.97931
#
# Printing values for iteration 6
#
# Printing Accuracy scores:  [0.95833333 0.95833333 0.95833333 0.95833333 0.97222222]
# Mean Accuracy:  0.96111
#
# Printing Precision scores:  [0.96491228 0.98113208 0.98245614 0.95081967 0.98181818]
# Mean Precision:  0.97223
#
# Printing ROC-AUC scores:  [0.95814732 0.99588477 0.99568966 0.96059113 0.9657754 ]
# Mean ROC-AUC:  0.97522
#
# Printing Recall scores:  [0.98214286 0.96296296 0.96551724 1.         0.98181818]
# Mean Recall:  0.97849
#
# Printing F1 scores:  [0.97345133 0.97196262 0.97391304 0.97478992 0.98181818]
# Mean F1:  0.97519
#
# Printing values for iteration 7
#
# Printing Accuracy scores:  [0.97222222 0.94444444 0.98611111 0.97222222 0.95833333]
# Mean Accuracy:  0.96667
#
# Printing Precision scores:  [0.96666667 0.93548387 1.         1.         0.96363636]
# Mean Precision:  0.97316
#
# Printing ROC-AUC scores:  [0.99507389 0.91625616 0.99944196 0.99465241 0.9372428 ]
# Mean ROC-AUC:  0.96853
#
# Printing Recall scores:  [1.         1.         0.98214286 0.96363636 0.98148148]
# Mean Recall:  0.98545
#
# Printing F1 scores:  [0.98305085 0.96666667 0.99099099 0.98148148 0.97247706]
# Mean F1:  0.97893
#
# Printing values for iteration 8
#
# Printing Accuracy scores:  [0.97222222 0.95833333 0.97222222 0.95833333 0.93055556]
# Mean Accuracy:  0.95833
#
# Printing Precision scores:  [0.98275862 0.96551724 0.98245614 0.96363636 0.94642857]
# Mean Precision:  0.96816
#
# Printing ROC-AUC scores:  [0.99568966 0.99415205 0.9625731  0.968107   0.95989305]
# Mean ROC-AUC:  0.97608
#
# Printing Recall scores:  [0.98275862 0.98245614 0.98245614 0.98148148 0.96363636]
# Mean Recall:  0.97856
#
# Printing F1 scores:  [0.98275862 0.97391304 0.98245614 0.97247706 0.95495495]
# Mean F1:  0.97331
#
# Printing values for iteration 9
#
# Printing Accuracy scores:  [0.97222222 0.97222222 0.95833333 0.90277778 0.95833333]
# Mean Accuracy:  0.95278
#
# Printing Precision scores:  [0.98305085 0.96666667 0.98275862 0.90909091 0.96296296]
# Mean Precision:  0.96091
#
# Printing ROC-AUC scores:  [0.99804433 0.96428571 0.95697523 0.95480769 0.98907646]
# Mean ROC-AUC:  0.97264
#
# Printing Recall scores:  [0.98305085 1.         0.96610169 0.96153846 0.98113208]
# Mean Recall:  0.97836
#
# Printing F1 scores:  [0.98305085 0.98305085 0.97435897 0.93457944 0.97196262]
# Mean F1:  0.9694
#
# Printing values for iteration 10
#
# Printing Accuracy scores:  [0.97222222 0.94444444 0.94444444 0.95833333 0.95833333]
# Mean Accuracy:  0.95556
#
# Printing Precision scores:  [0.98360656 0.94444444 1.         0.94545455 0.96491228]
# Mean Precision:  0.96768
#
# Printing ROC-AUC scores:  [0.99850969 0.97019231 0.9875     0.975      0.95926339]
# Mean ROC-AUC:  0.97809
#
# Printing Recall scores:  [0.98360656 0.98076923 0.93333333 1.         0.98214286]
# Mean Recall:  0.97597
#
# Printing F1 scores:  [0.98360656 0.96226415 0.96551724 0.97196262 0.97345133]
# Mean F1:  0.97136

# %%
print("Printing values for 10 iterations KNN")
# Calculate the mean and std accuracy
mean_accuracy = sum(accuracy_list) / len(accuracy_list)
std_accuracy = np.std(accuracy_list)

# Report the mean accuracy up to 4 decimal points
print(f"Mean Accuracy: {mean_accuracy : .4f}")
print(f"Std Accuracy: {std_accuracy : .4f}")

# Calculate the mean and std precision
mean_precision = sum(precision_list) / len(precision_list)
std_precision = np.std(precision_list)
# Report the mean precision up to 4 decimal points

print(f"Mean Precision: {mean_precision : .4f}")
print(f"Std Precision: {std_precision : .4f}")

# Calculate the mean and std recall
mean_recall = sum(recall_list) / len(recall_list)
std_recall = np.std(recall_list)
# Report the mean recall up to 4 decimal points

print(f"Mean Recall: {mean_recall : .4f}")
print(f"Std Recall: {std_recall : .4f}")

# Calculate the mean and std roc_auc
mean_roc_auc = sum(roc_auc_list) / len(roc_auc_list)
std_roc_auc = np.std(roc_auc_list)
# Report the mean roc_auc up to 4 decimal points

print(f"Mean ROC-AUC: {mean_roc_auc : .4f}")
print(f"Std ROC-AUC: {std_roc_auc : .4f}")

# Calculate the mean and std f1_score
mean_f1_score = sum(f1_score_list) / len(f1_score_list)
std_f1_score = np.std(f1_score_list)
# Report the mean f1-score up to 4 decimal points

print(f"Mean F1-Score: {mean_f1_score : .4f}")
print(f"Std F1-Score: {std_f1_score : .4f}")
# Out:
# Printing values for 10 iterations KNN
# Mean Accuracy:  0.9589
# Std Accuracy:  0.0072
# Mean Precision:  0.9673
# Std Precision:  0.0067
# Mean Recall:  0.9805
# Std Recall:  0.0037
# Mean ROC-AUC:  0.9720
# Std ROC-AUC:  0.0034
# Mean F1-Score:  0.9736
# Std F1-Score:  0.0050

# %%
# Naives Bayes
accuracy_list = []
precision_list = []
recall_list = []
roc_auc_list = []
f1_score_list = []

iterations = 10

for it in range(1,iterations+1):
    print(f"Printing values for iteration {it}\n")
    df_shuffled = df.sample(frac=1) # Shuffling the DataFrame 

    # Extracting values from the shuffled DataFrame in form of NumPy array
    X1= df_shuffled.iloc[:, :-1].values
    y1 = df_shuffled.iloc[:,-1].values

    naive_bayes = GaussianNB()
    pipeline_decision_tree = create_pipeline(naive_bayes)
    acc, precision, roc_auc, recall, f1_score = calculate_metrics(pipeline_decision_tree,X1,y1)
    accuracy_list.append(acc)
    precision_list.append(precision)
    roc_auc_list.append(roc_auc)
    recall_list.append(recall)
    f1_score_list.append(f1_score)
# Out:
# Printing values for iteration 1
#
# Printing Accuracy scores:  [0.94444444 0.94444444 0.95833333 0.90277778 0.91666667]
# Mean Accuracy:  0.93333
#
# Printing Precision scores:  [1.         0.94736842 0.98181818 0.93103448 0.93220339]
# Mean Precision:  0.95848
#
# Printing ROC-AUC scores:  [0.99107143 0.90374332 0.97098214 0.89766082 0.88011696]
# Mean ROC-AUC:  0.92871
#
# Printing Recall scores:  [0.92857143 0.98181818 0.96428571 0.94736842 0.96491228]
# Mean Recall:  0.95739
#
# Printing F1 scores:  [0.96296296 0.96428571 0.97297297 0.93913043 0.94827586]
# Mean F1:  0.95753
#
# Printing values for iteration 2
#
# Printing Accuracy scores:  [0.93055556 0.875      0.91666667 0.97222222 0.94444444]
# Mean Accuracy:  0.92778
#
# Printing Precision scores:  [0.96491228 0.90384615 0.95       1.         0.94915254]
# Mean Precision:  0.95358
#
# Printing ROC-AUC scores:  [0.90763547 0.92903828 0.97222222 0.97379679 0.92397661]
# Mean ROC-AUC:  0.94133
#
# Printing Recall scores:  [0.94827586 0.92156863 0.95       0.96363636 0.98245614]
# Mean Recall:  0.95319
#
# Printing F1 scores:  [0.95652174 0.91262136 0.95       0.98148148 0.96551724]
# Mean F1:  0.95323
#
# Printing values for iteration 3
#
# Printing Accuracy scores:  [0.97222222 0.91666667 0.95833333 0.94444444 0.90277778]
# Mean Accuracy:  0.93889
#
# Printing Precision scores:  [1.         0.92857143 0.98245614 0.96296296 0.92982456]
# Mean Precision:  0.96076
#
# Printing ROC-AUC scores:  [0.99087353 0.89454733 0.98275862 0.91975309 0.9609375 ]
# Mean ROC-AUC:  0.94977
#
# Printing Recall scores:  [0.96610169 0.96296296 0.96551724 0.96296296 0.94642857]
# Mean Recall:  0.96079
#
# Printing F1 scores:  [0.98275862 0.94545455 0.97391304 0.96296296 0.9380531 ]
# Mean F1:  0.96063
#
# Printing values for iteration 4
#
# Printing Accuracy scores:  [0.94444444 0.875      0.95833333 0.95833333 0.93055556]
# Mean Accuracy:  0.93333
#
# Printing Precision scores:  [0.98333333 0.89830508 1.         0.96296296 0.96153846]
# Mean Precision:  0.96123
#
# Printing ROC-AUC scores:  [0.925      0.93415179 0.97426901 0.99702085 0.94041708]
# Mean ROC-AUC:  0.95417
#
# Printing Recall scores:  [0.9516129  0.94642857 0.94736842 0.98113208 0.94339623]
# Mean Recall:  0.95399
#
# Printing F1 scores:  [0.96721311 0.92173913 0.97297297 0.97196262 0.95238095]
# Mean F1:  0.95725
#
# Printing values for iteration 5
#
# Printing Accuracy scores:  [0.90277778 0.98611111 0.95833333 0.91666667 0.88888889]
# Mean Accuracy:  0.93056
#
# Printing Precision scores:  [0.94642857 0.98245614 0.96491228 0.96296296 0.96153846]
# Mean Precision:  0.96366
#
# Printing ROC-AUC scores:  [0.94853801 0.99776786 0.92075893 0.93805804 0.91629464]
# Mean ROC-AUC:  0.94428
#
# Printing Recall scores:  [0.92982456 1.         0.98214286 0.92857143 0.89285714]
# Mean Recall:  0.94668
#
# Printing F1 scores:  [0.9380531  0.99115044 0.97345133 0.94545455 0.92592593]
# Mean F1:  0.95481
#
# Printing values for iteration 6
#
# Printing Accuracy scores:  [0.88888889 0.93055556 0.95833333 0.98611111 0.91666667]
# Mean Accuracy:  0.93611
#
# Printing Precision scores:  [0.9245283  0.96226415 0.98113208 0.98305085 0.98275862]
# Mean Precision:  0.96675
#
# Printing ROC-AUC scores:  [0.8877855  0.96450617 0.95833333 0.9612069  0.93870968]
# Mean ROC-AUC:  0.94211
#
# Printing Recall scores:  [0.9245283  0.94444444 0.96296296 1.         0.91935484]
# Mean Recall:  0.95026
#
# Printing F1 scores:  [0.9245283  0.95327103 0.97196262 0.99145299 0.95      ]
# Mean F1:  0.95824
#
# Printing values for iteration 7
#
# Printing Accuracy scores:  [0.90277778 0.91666667 0.97222222 0.93055556 0.875     ]
# Mean Accuracy:  0.91944
#
# Printing Precision scores:  [0.96428571 0.96226415 0.98181818 0.94827586 0.92592593]
# Mean Precision:  0.95651
#
# Printing ROC-AUC scores:  [0.91329857 0.93048128 0.99465241 0.94093567 0.85454545]
# Mean ROC-AUC:  0.92678
#
# Printing Recall scores:  [0.91525424 0.92727273 0.98181818 0.96491228 0.90909091]
# Mean Recall:  0.93967
#
# Printing F1 scores:  [0.93913043 0.94444444 0.98181818 0.95652174 0.91743119]
# Mean F1:  0.94787
#
# Printing values for iteration 8
#
# Printing Accuracy scores:  [0.97222222 0.93055556 0.91666667 0.93055556 0.91666667]
# Mean Accuracy:  0.93333
#
# Printing Precision scores:  [0.96153846 0.93333333 0.96078431 0.96428571 0.98333333]
# Mean Precision:  0.96066
#
# Printing ROC-AUC scores:  [0.95363636 0.89181287 0.96425025 0.92982456 0.94335938]
# Mean ROC-AUC:  0.93658
#
# Printing Recall scores:  [1.         0.98245614 0.9245283  0.94736842 0.921875  ]
# Mean Recall:  0.95525
#
# Printing F1 scores:  [0.98039216 0.95726496 0.94230769 0.95575221 0.9516129 ]
# Mean F1:  0.95747
#
# Printing values for iteration 9
#
# Printing Accuracy scores:  [0.93055556 0.97222222 0.97222222 0.93055556 0.86111111]
# Mean Accuracy:  0.93333
#
# Printing Precision scores:  [0.98275862 0.98181818 0.96363636 0.92727273 0.94642857]
# Mean Precision:  0.96038
#
# Printing ROC-AUC scores:  [0.95230999 0.99251337 0.99702085 0.93846154 0.85694444]
# Mean ROC-AUC:  0.94745
#
# Printing Recall scores:  [0.93442623 0.98181818 1.         0.98076923 0.88333333]
# Mean Recall:  0.95607
#
# Printing F1 scores:  [0.95798319 0.98181818 0.98148148 0.95327103 0.9137931 ]
# Mean F1:  0.95767
#
# Printing values for iteration 10
#
# Printing Accuracy scores:  [0.94444444 0.94444444 0.93055556 0.95833333 0.88888889]
# Mean Accuracy:  0.93333
#
# Printing Precision scores:  [0.98113208 0.98305085 0.93220339 0.94444444 0.94642857]
# Mean Precision:  0.95745
#
# Printing ROC-AUC scores:  [0.9631016  0.97317437 0.95145089 0.97525677 0.84667488]
# Mean ROC-AUC:  0.94193
#
# Printing Recall scores:  [0.94545455 0.95081967 0.98214286 1.         0.9137931 ]
# Mean Recall:  0.95844
#
# Printing F1 scores:  [0.96296296 0.96666667 0.95652174 0.97142857 0.92982456]
# Mean F1:  0.95748

# %%
print("Printing values for 10 iterations Naive Bayes")
# Calculate the mean and std accuracy
mean_accuracy = sum(accuracy_list) / len(accuracy_list)
std_accuracy = np.std(accuracy_list)

# Report the mean accuracy up to 4 decimal points
print(f"Mean Accuracy: {mean_accuracy : .4f}")
print(f"Std Accuracy: {std_accuracy : .4f}")

# Calculate the mean and std precision
mean_precision = sum(precision_list) / len(precision_list)
std_precision = np.std(precision_list)
# Report the mean precision up to 4 decimal points

print(f"Mean Precision: {mean_precision : .4f}")
print(f"Std Precision: {std_precision : .4f}")

# Calculate the mean and std recall
mean_recall = sum(recall_list) / len(recall_list)
std_recall = np.std(recall_list)
# Report the mean recall up to 4 decimal points

print(f"Mean Recall: {mean_recall : .4f}")
print(f"Std Recall: {std_recall : .4f}")

# Calculate the mean and std roc_auc
mean_roc_auc = sum(roc_auc_list) / len(roc_auc_list)
std_roc_auc = np.std(roc_auc_list)
# Report the mean roc_auc up to 4 decimal points

print(f"Mean ROC-AUC: {mean_roc_auc : .4f}")
print(f"Std ROC-AUC: {std_roc_auc : .4f}")

# Calculate the mean and std f1_score
mean_f1_score = sum(f1_score_list) / len(f1_score_list)
std_f1_score = np.std(f1_score_list)
# Report the mean f1-score up to 4 decimal points

print(f"Mean F1-Score: {mean_f1_score : .4f}")
print(f"Std F1-Score: {std_f1_score : .4f}")
# Out:
# Printing values for 10 iterations Naive Bayes
# Mean Accuracy:  0.9319
# Std Accuracy:  0.0050
# Mean Precision:  0.9599
# Std Precision:  0.0035
# Mean Recall:  0.9532
# Std Recall:  0.0059
# Mean ROC-AUC:  0.9413
# Std ROC-AUC:  0.0082
# Mean F1-Score:  0.9562
# Std F1-Score:  0.0033
