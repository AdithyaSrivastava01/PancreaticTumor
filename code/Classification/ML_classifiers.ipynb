# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

#Pipeline creation
from sklearn.pipeline import Pipeline

#Data processing modules
from sklearn.model_selection import train_test_split
from sklearn.model_selection import KFold
from sklearn.preprocessing import MinMaxScaler
from sklearn.model_selection import cross_val_score, cross_val_predict

#importing various Ml classifiers
from sklearn.tree import DecisionTreeClassifier
from xgboost import XGBClassifier
from sklearn.ensemble import AdaBoostClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.svm import SVC
from sklearn.neighbors import KNeighborsClassifier
from sklearn.naive_bayes import GaussianNB

#Importing Metric modules
from sklearn.metrics import accuracy_score, confusion_matrix, classification_report, roc_auc_score, f1_score

# %%
# Extracted Features path
healthy_features_path = 'featuresvalues_new2D_automated.csv'
tumor_features_path = 'tumorfeaturesvalues_new2D_automated_70.csv'

# %%
# Reading the healthy pancreas features
data = pd.read_csv(healthy_features_path)
X_healthy = data.iloc[:, :-1]
y_healthy = data.iloc[:, -1]

# %%
# Reading the tumor pancreas features
data_tumor = pd.read_csv(tumor_features_path)
X_tumor = data_tumor.iloc[:, :-1]
y_tumor = data_tumor.iloc[:, -1]

# %%
# data_tumor

# %%
y_healthy.shape
# Out:
# (89,)

# %%
# Concat Features
z=y_tumor.values.reshape(256,1)
h = y_healthy.values.reshape(89,1)
modified_array = np.vstack((z, h))
y = modified_array.reshape(1,345)

# %%
X_tumor.shape
# Out:
# (256, 102)

# %%
z1=X_tumor.values.reshape(256,102)
h1 = X_healthy.values.reshape(89,102)
modified_array = np.vstack((z1, h1))
X = modified_array.reshape(102,345)

# %%
X =X.reshape(345,102)
y = y.reshape(345,1)

# %%
modified_data = np.hstack((X,y))
df = pd.DataFrame(modified_data)

# %%
#Pipeline Creation
#Pipeline contains a MinMaxScaler and a classifier

def create_pipeline(classifier):
    steps = list()
    steps.append(("scaler",MinMaxScaler()))
    steps.append(("classifier",classifier))
    pipeline = Pipeline(steps=steps)
    return pipeline

# %%
# 5 fold CV evaluation

def calculate_metrics(pipeline,X,y):
    kfold = KFold(n_splits=5, shuffle=True, random_state=42)

    # Accuracy
    scores_accuracy = cross_val_score(pipeline, X, y, cv=kfold,scoring="accuracy")

    # Print the cross-validation scores
    print("Printing Accuracy scores: ", scores_accuracy)
    print("Mean Accuracy: ", round(np.mean(scores_accuracy),5),'\n')


    # Precision
    scores_precision = cross_val_score(pipeline, X, y, cv=kfold,scoring="precision")

    # Print the cross-validation scores
    print("Printing Precision scores: ", scores_precision)
    print("Mean Precision: ", round(np.mean(scores_precision),5),'\n')

    # ROC-AUC
    scores_roc_auc = cross_val_score(pipeline, X, y, cv=kfold,scoring="roc_auc")

    # Print the cross-validation scores
    print("Printing ROC-AUC scores: ", scores_roc_auc)
    print("Mean ROC-AUC: ", round(np.mean(scores_roc_auc),5),'\n')

    # Recall
    scores_recall = cross_val_score(pipeline, X, y, cv=kfold,scoring="recall")

    # Print the cross-validation scores
    print("Printing Recall scores: ", scores_recall)
    print("Mean Recall: ", round(np.mean(scores_recall),5),'\n')


    # F1-score
    scores_f1 = cross_val_score(pipeline, X, y, cv=kfold,scoring="f1")

    # Print the cross-validation scores
    print("Printing F1 scores: ", scores_f1)
    print("Mean F1: ", round(np.mean(scores_f1),5),'\n')

    return (round(np.mean(scores_accuracy),5),round(np.mean(scores_precision),5),round(np.mean(scores_roc_auc),5),round(np.mean(scores_recall),5),round(np.mean(scores_f1),5))

# %%
# Decision Tree
accuracy_list = []
precision_list = []
recall_list = []
roc_auc_list = []
f1_score_list = []

iterations = 10

for it in range(1,iterations+1):
    print(f"Printing values for iteration {it}\n")
    df_shuffled = df.sample(frac=1) # Shuffling the DataFrame 

    # Extracting values from the shuffled DataFrame in form of NumPy array
    X1= df_shuffled.iloc[:, :-1].values
    y1 = df_shuffled.iloc[:,-1].values

    decision_tree = DecisionTreeClassifier(criterion = "gini",random_state=42)
    pipeline_decision_tree = create_pipeline(decision_tree)
    acc, precision, roc_auc, recall, f1_score = calculate_metrics(pipeline_decision_tree,X1,y1)
    accuracy_list.append(acc)
    precision_list.append(precision)
    roc_auc_list.append(roc_auc)
    recall_list.append(recall)
    f1_score_list.append(f1_score)
# Out:
# Printing values for iteration 1
#
# Printing Accuracy scores:  [0.85507246 0.91304348 0.97101449 0.8115942  0.88405797]
# Mean Accuracy:  0.88696
#
# Printing Precision scores:  [0.92156863 0.95744681 1.         0.91111111 0.88      ]
# Mean Precision:  0.93403
#
# Printing ROC-AUC scores:  [0.81839623 0.90918367 0.98275862 0.80473684 0.84782609]
# Mean ROC-AUC:  0.87258
#
# Printing Recall scores:  [0.88679245 0.91836735 0.96551724 0.82       0.95652174]
# Mean Recall:  0.90944
#
# Printing F1 scores:  [0.90384615 0.9375     0.98245614 0.86315789 0.91666667]
# Mean F1:  0.92073
#
# Printing values for iteration 2
#
# Printing Accuracy scores:  [0.82608696 0.92753623 0.94202899 0.92753623 0.86956522]
# Mean Accuracy:  0.89855
#
# Printing Precision scores:  [0.9        0.96       0.93877551 0.94827586 0.93478261]
# Mean Precision:  0.93637
#
# Printing ROC-AUC scores:  [0.78563348 0.91503268 0.92117988 0.85745614 0.86377551]
# Mean ROC-AUC:  0.86862
#
# Printing Recall scores:  [0.86538462 0.94117647 0.9787234  0.96491228 0.87755102]
# Mean Recall:  0.92555
#
# Printing F1 scores:  [0.88235294 0.95049505 0.95833333 0.95652174 0.90526316]
# Mean F1:  0.93059
#
# Printing values for iteration 3
#
# Printing Accuracy scores:  [0.92753623 0.88405797 0.91304348 0.82608696 0.7826087 ]
# Mean Accuracy:  0.86667
#
# Printing Precision scores:  [0.97826087 0.96226415 0.93877551 0.85714286 0.88235294]
# Mean Precision:  0.92376
#
# Printing ROC-AUC scores:  [0.93418367 0.86403509 0.89438776 0.7877176  0.71666667]
# Mean ROC-AUC:  0.8394
#
# Printing Recall scores:  [0.91836735 0.89473684 0.93877551 0.89361702 0.83333333]
# Mean Recall:  0.89577
#
# Printing F1 scores:  [0.94736842 0.92727273 0.93877551 0.875      0.85714286]
# Mean F1:  0.90911
#
# Printing values for iteration 4
#
# Printing Accuracy scores:  [0.91304348 0.88405797 0.88405797 0.89855072 0.91304348]
# Mean Accuracy:  0.89855
#
# Printing Precision scores:  [0.98076923 0.92592593 0.93877551 0.89795918 0.97777778]
# Mean Precision:  0.94424
#
# Printing ROC-AUC scores:  [0.9168956  0.82962963 0.86764706 0.86956522 0.92397959]
# Mean ROC-AUC:  0.88154
#
# Printing Recall scores:  [0.91071429 0.92592593 0.90196078 0.95652174 0.89795918]
# Mean Recall:  0.91862
#
# Printing F1 scores:  [0.94444444 0.92592593 0.92       0.92631579 0.93617021]
# Mean F1:  0.93057
#
# Printing values for iteration 5
#
# Printing Accuracy scores:  [0.91304348 0.91304348 0.95652174 0.86956522 0.92753623]
# Mean Accuracy:  0.91594
#
# Printing Precision scores:  [0.93877551 0.94117647 0.94444444 0.93877551 0.96153846]
# Mean Precision:  0.94494
#
# Printing ROC-AUC scores:  [0.89438776 0.8872549  0.91666667 0.8540724  0.90919811]
# Mean ROC-AUC:  0.89232
#
# Printing Recall scores:  [0.93877551 0.94117647 1.         0.88461538 0.94339623]
# Mean Recall:  0.94159
#
# Printing F1 scores:  [0.93877551 0.94117647 0.97142857 0.91089109 0.95238095]
# Mean F1:  0.94293
#
# Printing values for iteration 6
#
# Printing Accuracy scores:  [0.86956522 0.91304348 0.88405797 0.86956522 0.88405797]
# Mean Accuracy:  0.88406
#
# Printing Precision scores:  [0.94117647 0.92727273 0.93478261 0.90196078 0.95744681]
# Mean Precision:  0.93253
#
# Printing ROC-AUC scores:  [0.84444444 0.85613208 0.8764881  0.82842105 0.88562092]
# Mean ROC-AUC:  0.85822
#
# Printing Recall scores:  [0.88888889 0.96226415 0.89583333 0.92       0.88235294]
# Mean Recall:  0.90987
#
# Printing F1 scores:  [0.91428571 0.94444444 0.91489362 0.91089109 0.91836735]
# Mean F1:  0.92058
#
# Printing values for iteration 7
#
# Printing Accuracy scores:  [0.91304348 0.85507246 0.86956522 0.84057971 0.95652174]
# Mean Accuracy:  0.88696
#
# Printing Precision scores:  [0.96153846 0.88679245 0.88       0.92       1.        ]
# Mean Precision:  0.92967
#
# Printing ROC-AUC scores:  [0.8962963  0.79411765 0.83172147 0.80896226 0.97058824]
# Mean ROC-AUC:  0.86034
#
# Printing Recall scores:  [0.92592593 0.92156863 0.93617021 0.86792453 0.94117647]
# Mean Recall:  0.91855
#
# Printing F1 scores:  [0.94339623 0.90384615 0.90721649 0.89320388 0.96969697]
# Mean F1:  0.92347
#
# Printing values for iteration 8
#
# Printing Accuracy scores:  [0.92753623 0.82608696 0.89855072 0.88405797 0.94202899]
# Mean Accuracy:  0.89565
#
# Printing Precision scores:  [0.97777778 0.91836735 0.89795918 0.94642857 0.94339623]
# Mean Precision:  0.93679
#
# Printing ROC-AUC scores:  [0.93452381 0.7995283  0.86956522 0.82053292 0.90686275]
# Mean ROC-AUC:  0.8662
#
# Printing Recall scores:  [0.91666667 0.8490566  0.95652174 0.9137931  0.98039216]
# Mean Recall:  0.92329
#
# Printing F1 scores:  [0.94623656 0.88235294 0.92631579 0.92982456 0.96153846]
# Mean F1:  0.92925
#
# Printing values for iteration 9
#
# Printing Accuracy scores:  [0.86956522 0.85507246 0.89855072 0.88405797 0.89855072]
# Mean Accuracy:  0.88116
#
# Printing Precision scores:  [0.90384615 0.91489362 0.92       0.98076923 0.90384615]
# Mean Precision:  0.92467
#
# Printing ROC-AUC scores:  [0.82189542 0.83877551 0.86938776 0.89420063 0.85459184]
# Mean ROC-AUC:  0.85577
#
# Printing Recall scores:  [0.92156863 0.87755102 0.93877551 0.87931034 0.95918367]
# Mean Recall:  0.91528
#
# Printing F1 scores:  [0.91262136 0.89583333 0.92929293 0.92727273 0.93069307]
# Mean F1:  0.91914
#
# Printing values for iteration 10
#
# Printing Accuracy scores:  [0.85507246 0.91304348 0.91304348 0.86956522 0.91304348]
# Mean Accuracy:  0.89275
#
# Printing Precision scores:  [0.9        0.91071429 1.         0.90196078 0.90566038]
# Mean Precision:  0.92367
#
# Printing ROC-AUC scores:  [0.81842105 0.84332579 0.94545455 0.82842105 0.86479592]
# Mean ROC-AUC:  0.86008
#
# Printing Recall scores:  [0.9        0.98076923 0.89090909 0.92       0.97959184]
# Mean Recall:  0.93425
#
# Printing F1 scores:  [0.9        0.94444444 0.94230769 0.91089109 0.94117647]
# Mean F1:  0.92776

# %%
print("Printing values for 10 iterations Decision Tree")
# Calculate the mean and std accuracy
mean_accuracy = sum(accuracy_list) / len(accuracy_list)
std_accuracy = np.std(accuracy_list)

# Report the mean accuracy up to 4 decimal points
print(f"Mean Accuracy: {mean_accuracy : .4f}")
print(f"Std Accuracy: {std_accuracy : .4f}")

# Calculate the mean and std precision
mean_precision = sum(precision_list) / len(precision_list)
std_precision = np.std(precision_list)
# Report the mean precision up to 4 decimal points

print(f"Mean Precision: {mean_precision : .4f}")
print(f"Std Precision: {std_precision : .4f}")

# Calculate the mean and std recall
mean_recall = sum(recall_list) / len(recall_list)
std_recall = np.std(recall_list)
# Report the mean recall up to 4 decimal points

print(f"Mean Recall: {mean_recall : .4f}")
print(f"Std Recall: {std_recall : .4f}")

# Calculate the mean and std roc_auc
mean_roc_auc = sum(roc_auc_list) / len(roc_auc_list)
std_roc_auc = np.std(roc_auc_list)
# Report the mean roc_auc up to 4 decimal points

print(f"Mean ROC-AUC: {mean_roc_auc : .4f}")
print(f"Std ROC-AUC: {std_roc_auc : .4f}")

# Calculate the mean and std f1_score
mean_f1_score = sum(f1_score_list) / len(f1_score_list)
std_f1_score = np.std(f1_score_list)
# Report the mean f1-score up to 4 decimal points

print(f"Mean F1-Score: {mean_f1_score : .4f}")
print(f"Std F1-Score: {std_f1_score : .4f}")
# Out:
# Printing values for 10 iterations Decision Tree
# Mean Accuracy:  0.8907
# Std Accuracy:  0.0124
# Mean Precision:  0.9331
# Std Precision:  0.0074
# Mean Recall:  0.9192
# Std Recall:  0.0124
# Mean ROC-AUC:  0.8655
# Std ROC-AUC:  0.0139
# Mean F1-Score:  0.9254
# Std F1-Score:  0.0086

# %%
# AdaBoost
accuracy_list = []
precision_list = []
recall_list = []
roc_auc_list = []
f1_score_list = []

iterations = 10

for it in range(1,iterations+1):
    print(f"Printing values for iteration {it}\n")
    df_shuffled = df.sample(frac=1) # Shuffling the DataFrame 

    # Extracting values from the shuffled DataFrame in form of NumPy array
    X1= df_shuffled.iloc[:, :-1].values
    y1 = df_shuffled.iloc[:,-1].values

    adaboost = AdaBoostClassifier(n_estimators=50, random_state=42)
    pipeline_decision_tree = create_pipeline(adaboost)
    acc, precision, roc_auc, recall, f1_score = calculate_metrics(pipeline_decision_tree,X1,y1)
    accuracy_list.append(acc)
    precision_list.append(precision)
    roc_auc_list.append(roc_auc)
    recall_list.append(recall)
    f1_score_list.append(f1_score)
# Out:
# Printing values for iteration 1
#
# Printing Accuracy scores:  [0.86956522 0.95652174 0.97101449 0.95652174 0.94202899]
# Mean Accuracy:  0.93913
#
# Printing Precision scores:  [0.90909091 0.98076923 0.98181818 0.96078431 0.95454545]
# Mean Precision:  0.9574
#
# Printing ROC-AUC scores:  [0.95308642 0.96108491 0.94415584 0.99368421 0.97909091]
# Mean ROC-AUC:  0.96622
#
# Printing Recall scores:  [0.92592593 0.96226415 0.98181818 0.98       0.95454545]
# Mean Recall:  0.96091
#
# Printing F1 scores:  [0.91743119 0.97142857 0.98181818 0.97029703 0.95454545]
# Mean F1:  0.9591
#
# Printing values for iteration 2
#
# Printing Accuracy scores:  [0.98550725 0.89855072 0.91304348 0.94202899 0.91304348]
# Mean Accuracy:  0.93043
#
# Printing Precision scores:  [1.         0.91071429 0.91836735 0.95918367 0.95918367]
# Mean Precision:  0.94949
#
# Printing ROC-AUC scores:  [1.         0.93632075 0.98259188 0.99285714 0.96840959]
# Mean ROC-AUC:  0.97604
#
# Printing Recall scores:  [0.98214286 0.96226415 0.95744681 0.95918367 0.92156863]
# Mean Recall:  0.95652
#
# Printing F1 scores:  [0.99099099 0.93577982 0.9375     0.95918367 0.94      ]
# Mean F1:  0.95269
#
# Printing values for iteration 3
#
# Printing Accuracy scores:  [0.94202899 0.91304348 0.92753623 0.94202899 0.94202899]
# Mean Accuracy:  0.93333
#
# Printing Precision scores:  [0.97826087 0.98214286 0.92       0.94444444 0.9245283 ]
# Mean Precision:  0.94988
#
# Printing ROC-AUC scores:  [0.97916667 0.98518519 0.93423598 0.9841629  0.98877551]
# Mean ROC-AUC:  0.97431
#
# Printing Recall scores:  [0.9375     0.91666667 0.9787234  0.98076923 1.        ]
# Mean Recall:  0.96273
#
# Printing F1 scores:  [0.95744681 0.94827586 0.94845361 0.96226415 0.96078431]
# Mean F1:  0.95544
#
# Printing values for iteration 4
#
# Printing Accuracy scores:  [0.89855072 0.88405797 0.98550725 0.92753623 0.98550725]
# Mean Accuracy:  0.93623
#
# Printing Precision scores:  [0.94736842 0.88679245 0.98113208 0.91836735 1.        ]
# Mean Precision:  0.94673
#
# Printing ROC-AUC scores:  [0.93730408 0.92755102 1.         0.97731569 0.99455338]
# Mean ROC-AUC:  0.96734
#
# Printing Recall scores:  [0.93103448 0.95918367 1.         0.97826087 0.98039216]
# Mean Recall:  0.96977
#
# Printing F1 scores:  [0.93913043 0.92156863 0.99047619 0.94736842 0.99009901]
# Mean F1:  0.95773
#
# Printing values for iteration 5
#
# Printing Accuracy scores:  [0.89855072 0.92753623 0.92753623 0.94202899 0.94202899]
# Mean Accuracy:  0.92754
#
# Printing Precision scores:  [0.92727273 0.96078431 0.93877551 0.96226415 0.94117647]
# Mean Precision:  0.94605
#
# Printing ROC-AUC scores:  [0.95802469 0.96493213 0.97123016 0.9504717  0.97755102]
# Mean ROC-AUC:  0.96444
#
# Printing Recall scores:  [0.94444444 0.94230769 0.95833333 0.96226415 0.97959184]
# Mean Recall:  0.95739
#
# Printing F1 scores:  [0.93577982 0.95145631 0.94845361 0.96226415 0.96      ]
# Mean F1:  0.95159
#
# Printing values for iteration 6
#
# Printing Accuracy scores:  [0.98550725 0.94202899 0.92753623 0.94202899 0.94202899]
# Mean Accuracy:  0.94783
#
# Printing Precision scores:  [1.         0.96       0.94339623 0.94339623 0.94230769]
# Mean Precision:  0.95782
#
# Printing ROC-AUC scores:  [0.98349057 0.99052632 0.99208145 0.94117647 0.98210526]
# Mean ROC-AUC:  0.97788
#
# Printing Recall scores:  [0.98113208 0.96       0.96153846 0.98039216 0.98      ]
# Mean Recall:  0.97261
#
# Printing F1 scores:  [0.99047619 0.96       0.95238095 0.96153846 0.96078431]
# Mean F1:  0.96504
#
# Printing values for iteration 7
#
# Printing Accuracy scores:  [0.95652174 0.88405797 0.92753623 0.92753623 0.94202899]
# Mean Accuracy:  0.92754
#
# Printing Precision scores:  [0.98       0.94339623 0.92156863 0.9245283  0.96153846]
# Mean Precision:  0.94621
#
# Printing ROC-AUC scores:  [0.97930283 0.96883117 0.96031746 0.98526316 0.92307692]
# Mean ROC-AUC:  0.96336
#
# Printing Recall scores:  [0.96078431 0.90909091 0.97916667 0.98       0.96153846]
# Mean Recall:  0.95812
#
# Printing F1 scores:  [0.97029703 0.92592593 0.94949495 0.95145631 0.96153846]
# Mean F1:  0.95174
#
# Printing values for iteration 8
#
# Printing Accuracy scores:  [0.94202899 0.95652174 0.95652174 0.91304348 0.89855072]
# Mean Accuracy:  0.93333
#
# Printing Precision scores:  [0.9245283  0.98181818 0.98076923 0.94117647 0.9       ]
# Mean Precision:  0.94566
#
# Printing ROC-AUC scores:  [0.95204082 0.97664835 0.99528302 0.96840959 0.92843327]
# Mean ROC-AUC:  0.96416
#
# Printing Recall scores:  [1.         0.96428571 0.96226415 0.94117647 0.95744681]
# Mean Recall:  0.96503
#
# Printing F1 scores:  [0.96078431 0.97297297 0.97142857 0.94117647 0.92783505]
# Mean F1:  0.95484
#
# Printing values for iteration 9
#
# Printing Accuracy scores:  [0.91304348 0.97101449 0.89855072 0.94202899 0.88405797]
# Mean Accuracy:  0.92174
#
# Printing Precision scores:  [0.89285714 0.98113208 0.94736842 0.96153846 0.87234043]
# Mean Precision:  0.93105
#
# Printing ROC-AUC scores:  [0.98105263 0.99410377 0.97492163 0.94230769 0.96690519]
# Mean ROC-AUC:  0.97186
#
# Printing Recall scores:  [1.         0.98113208 0.93103448 0.96153846 0.95348837]
# Mean Recall:  0.96544
#
# Printing F1 scores:  [0.94339623 0.98113208 0.93913043 0.96153846 0.91111111]
# Mean F1:  0.94726
#
# Printing values for iteration 10
#
# Printing Accuracy scores:  [0.89855072 0.95652174 0.94202899 0.89855072 0.97101449]
# Mean Accuracy:  0.93333
#
# Printing Precision scores:  [0.92307692 0.96078431 0.94444444 0.91666667 0.96551724]
# Mean Precision:  0.9421
#
# Printing ROC-AUC scores:  [0.96514161 0.99368421 0.97511312 0.93133462 0.99587912]
# Mean ROC-AUC:  0.97223
#
# Printing Recall scores:  [0.94117647 0.98       0.98076923 0.93617021 1.        ]
# Mean Recall:  0.96762
#
# Printing F1 scores:  [0.93203883 0.97029703 0.96226415 0.92631579 0.98245614]
# Mean F1:  0.95467

# %%
print("Printing values for 10 iterations AdaBoost")
# Calculate the mean and std accuracy
mean_accuracy = sum(accuracy_list) / len(accuracy_list)
std_accuracy = np.std(accuracy_list)

# Report the mean accuracy up to 4 decimal points
print(f"Mean Accuracy: {mean_accuracy : .4f}")
print(f"Std Accuracy: {std_accuracy : .4f}")

# Calculate the mean and std precision
mean_precision = sum(precision_list) / len(precision_list)
std_precision = np.std(precision_list)
# Report the mean precision up to 4 decimal points

print(f"Mean Precision: {mean_precision : .4f}")
print(f"Std Precision: {std_precision : .4f}")

# Calculate the mean and std recall
mean_recall = sum(recall_list) / len(recall_list)
std_recall = np.std(recall_list)
# Report the mean recall up to 4 decimal points

print(f"Mean Recall: {mean_recall : .4f}")
print(f"Std Recall: {std_recall : .4f}")

# Calculate the mean and std roc_auc
mean_roc_auc = sum(roc_auc_list) / len(roc_auc_list)
std_roc_auc = np.std(roc_auc_list)
# Report the mean roc_auc up to 4 decimal points

print(f"Mean ROC-AUC: {mean_roc_auc : .4f}")
print(f"Std ROC-AUC: {std_roc_auc : .4f}")

# Calculate the mean and std f1_score
mean_f1_score = sum(f1_score_list) / len(f1_score_list)
std_f1_score = np.std(f1_score_list)
# Report the mean f1-score up to 4 decimal points

print(f"Mean F1-Score: {mean_f1_score : .4f}")
print(f"Std F1-Score: {std_f1_score : .4f}")
# Out:
# Printing values for 10 iterations AdaBoost
# Mean Accuracy:  0.9330
# Std Accuracy:  0.0068
# Mean Precision:  0.9472
# Std Precision:  0.0072
# Mean Recall:  0.9636
# Std Recall:  0.0052
# Mean ROC-AUC:  0.9698
# Std ROC-AUC:  0.0051
# Mean F1-Score:  0.9550
# Std F1-Score:  0.0046

# %%
# XGBoost
accuracy_list = []
precision_list = []
recall_list = []
roc_auc_list = []
f1_score_list = []

iterations = 10

for it in range(1,iterations+1):
    print(f"Printing values for iteration {it}\n")
    df_shuffled = df.sample(frac=1) # Shuffling the DataFrame 

    # Extracting values from the shuffled DataFrame in form of NumPy array
    X1= df_shuffled.iloc[:, :-1].values
    y1 = df_shuffled.iloc[:,-1].values

    xgb_classifier = XGBClassifier(n_estimators=100, learning_rate=0.01, random_state=42)
    pipeline_decision_tree = create_pipeline(xgb_classifier)
    acc, precision, roc_auc, recall, f1_score = calculate_metrics(pipeline_decision_tree,X1,y1)
    accuracy_list.append(acc)
    precision_list.append(precision)
    roc_auc_list.append(roc_auc)
    recall_list.append(recall)
    f1_score_list.append(f1_score)
# Out:
# Printing values for iteration 1
#
# Printing Accuracy scores:  [0.91304348 0.92753623 0.92753623 0.88405797 0.92753623]
# Mean Accuracy:  0.91594
#
# Printing Precision scores:  [0.91836735 0.92857143 0.96153846 0.94       0.91071429]
# Mean Precision:  0.93184
#
# Printing ROC-AUC scores:  [0.95841393 0.96933962 0.9321934  0.96153846 0.96949891]
# Mean ROC-AUC:  0.9582
#
# Printing Recall scores:  [0.95744681 0.98113208 0.94339623 0.90384615 1.        ]
# Mean Recall:  0.95716
#
# Printing F1 scores:  [0.9375     0.95412844 0.95238095 0.92156863 0.95327103]
# Mean F1:  0.94377
#
# Printing values for iteration 2
#
# Printing Accuracy scores:  [0.94202899 0.84057971 0.91304348 0.91304348 0.88405797]
# Mean Accuracy:  0.89855
#
# Printing Precision scores:  [0.96363636 0.8245614  0.88888889 0.96666667 0.85714286]
# Mean Precision:  0.90018
#
# Printing ROC-AUC scores:  [0.92532468 0.97718254 0.99206349 0.7983871  0.98747764]
# Mean ROC-AUC:  0.93609
#
# Printing Recall scores:  [0.96363636 0.97916667 1.         0.93548387 0.97674419]
# Mean Recall:  0.97101
#
# Printing F1 scores:  [0.96363636 0.8952381  0.94117647 0.95081967 0.91304348]
# Mean F1:  0.93278
#
# Printing values for iteration 3
#
# Printing Accuracy scores:  [0.89855072 0.88405797 0.91304348 0.94202899 0.92753623]
# Mean Accuracy:  0.91304
#
# Printing Precision scores:  [0.96078431 0.89830508 0.88461538 0.92592593 0.92592593]
# Mean Precision:  0.91911
#
# Printing ROC-AUC scores:  [0.97160494 0.90064935 0.9905482  0.99473684 0.87581699]
# Mean ROC-AUC:  0.94667
#
# Printing Recall scores:  [0.90740741 0.96363636 1.         1.         0.98039216]
# Mean Recall:  0.97029
#
# Printing F1 scores:  [0.93333333 0.92982456 0.93877551 0.96153846 0.95238095]
# Mean F1:  0.94317
#
# Printing values for iteration 4
#
# Printing Accuracy scores:  [0.95652174 0.88405797 0.97101449 0.89855072 0.86956522]
# Mean Accuracy:  0.91594
#
# Printing Precision scores:  [0.96226415 0.875      0.98076923 0.89090909 0.89090909]
# Mean Precision:  0.91997
#
# Printing ROC-AUC scores:  [0.98585973 0.90736842 0.99547511 0.98473684 0.89875566]
# Mean ROC-AUC:  0.95444
#
# Printing Recall scores:  [0.98076923 0.98       0.98076923 0.98       0.94230769]
# Mean Recall:  0.97277
#
# Printing F1 scores:  [0.97142857 0.9245283  0.98076923 0.93333333 0.91588785]
# Mean F1:  0.94519
#
# Printing values for iteration 5
#
# Printing Accuracy scores:  [0.89855072 0.92753623 0.94202899 0.85507246 0.94202899]
# Mean Accuracy:  0.91304
#
# Printing Precision scores:  [0.91071429 0.92156863 0.94545455 0.83636364 0.94736842]
# Mean Precision:  0.91229
#
# Printing ROC-AUC scores:  [0.88738208 0.93849206 0.98525943 0.95116054 0.99350649]
# Mean ROC-AUC:  0.95116
#
# Printing Recall scores:  [0.96226415 0.97916667 0.98113208 0.9787234  0.98181818]
# Mean Recall:  0.97662
#
# Printing F1 scores:  [0.93577982 0.94949495 0.96296296 0.90196078 0.96428571]
# Mean F1:  0.9429
#
# Printing values for iteration 6
#
# Printing Accuracy scores:  [0.91304348 0.91304348 0.91304348 0.85507246 0.92753623]
# Mean Accuracy:  0.90435
#
# Printing Precision scores:  [0.88679245 0.94642857 0.92307692 0.85454545 0.94545455]
# Mean Precision:  0.91126
#
# Printing ROC-AUC scores:  [0.98259188 0.97115385 0.96894737 0.90918367 0.92098765]
# Mean ROC-AUC:  0.95057
#
# Printing Recall scores:  [1.         0.94642857 0.96       0.95918367 0.96296296]
# Mean Recall:  0.96572
#
# Printing F1 scores:  [0.94       0.94642857 0.94117647 0.90384615 0.95412844]
# Mean F1:  0.93712
#
# Printing values for iteration 7
#
# Printing Accuracy scores:  [0.88405797 0.92753623 0.91304348 0.92753623 0.91304348]
# Mean Accuracy:  0.91304
#
# Printing Precision scores:  [0.85964912 0.93220339 0.90384615 0.93617021 0.94736842]
# Mean Precision:  0.91585
#
# Printing ROC-AUC scores:  [0.99795918 0.93612637 0.95734127 0.95699433 0.92251462]
# Mean ROC-AUC:  0.95419
#
# Printing Recall scores:  [1.         0.98214286 0.97916667 0.95652174 0.94736842]
# Mean Recall:  0.97304
#
# Printing F1 scores:  [0.9245283  0.95652174 0.94       0.94623656 0.94736842]
# Mean F1:  0.94293
#
# Printing values for iteration 8
#
# Printing Accuracy scores:  [0.94202899 0.94202899 0.86956522 0.92753623 0.94202899]
# Mean Accuracy:  0.92464
#
# Printing Precision scores:  [0.98148148 0.96226415 0.85714286 0.91489362 0.93103448]
# Mean Precision:  0.92936
#
# Printing ROC-AUC scores:  [0.96428571 0.98820755 0.96836735 0.94090909 0.93580247]
# Mean ROC-AUC:  0.95951
#
# Printing Recall scores:  [0.94642857 0.96226415 0.97959184 0.97727273 1.        ]
# Mean Recall:  0.97311
#
# Printing F1 scores:  [0.96363636 0.96226415 0.91428571 0.94505495 0.96428571]
# Mean F1:  0.94991
#
# Printing values for iteration 9
#
# Printing Accuracy scores:  [0.89855072 0.91304348 0.92753623 0.97101449 0.88405797]
# Mean Accuracy:  0.91884
#
# Printing Precision scores:  [0.95918367 0.90909091 0.92       0.98214286 0.88888889]
# Mean Precision:  0.93186
#
# Printing ROC-AUC scores:  [0.91798643 0.94716776 0.98259188 0.99450549 0.96526316]
# Mean ROC-AUC:  0.9615
#
# Printing Recall scores:  [0.90384615 0.98039216 0.9787234  0.98214286 0.96      ]
# Mean Recall:  0.96102
#
# Printing F1 scores:  [0.93069307 0.94339623 0.94845361 0.98214286 0.92307692]
# Mean F1:  0.94555
#
# Printing values for iteration 10
#
# Printing Accuracy scores:  [0.86956522 0.92753623 0.92753623 0.86956522 0.94202899]
# Mean Accuracy:  0.90725
#
# Printing Precision scores:  [0.875      0.92592593 0.95833333 0.83928571 0.98214286]
# Mean Precision:  0.91614
#
# Printing ROC-AUC scores:  [0.96405229 0.92374728 0.97704082 0.97001934 0.94749216]
# Mean ROC-AUC:  0.95647
#
# Printing Recall scores:  [0.96078431 0.98039216 0.93877551 1.         0.94827586]
# Mean Recall:  0.96565
#
# Printing F1 scores:  [0.91588785 0.95238095 0.94845361 0.91262136 0.96491228]
# Mean F1:  0.93885

# %%
print("Printing values for 10 iterations XGBoost")
# Calculate the mean and std accuracy
mean_accuracy = sum(accuracy_list) / len(accuracy_list)
std_accuracy = np.std(accuracy_list)

# Report the mean accuracy up to 4 decimal points
print(f"Mean Accuracy: {mean_accuracy : .4f}")
print(f"Std Accuracy: {std_accuracy : .4f}")

# Calculate the mean and std precision
mean_precision = sum(precision_list) / len(precision_list)
std_precision = np.std(precision_list)
# Report the mean precision up to 4 decimal points

print(f"Mean Precision: {mean_precision : .4f}")
print(f"Std Precision: {std_precision : .4f}")

# Calculate the mean and std recall
mean_recall = sum(recall_list) / len(recall_list)
std_recall = np.std(recall_list)
# Report the mean recall up to 4 decimal points

print(f"Mean Recall: {mean_recall : .4f}")
print(f"Std Recall: {std_recall : .4f}")

# Calculate the mean and std roc_auc
mean_roc_auc = sum(roc_auc_list) / len(roc_auc_list)
std_roc_auc = np.std(roc_auc_list)
# Report the mean roc_auc up to 4 decimal points

print(f"Mean ROC-AUC: {mean_roc_auc : .4f}")
print(f"Std ROC-AUC: {std_roc_auc : .4f}")

# Calculate the mean and std f1_score
mean_f1_score = sum(f1_score_list) / len(f1_score_list)
std_f1_score = np.std(f1_score_list)
# Report the mean f1-score up to 4 decimal points

print(f"Mean F1-Score: {mean_f1_score : .4f}")
print(f"Std F1-Score: {std_f1_score : .4f}")
# Out:
# Printing values for 10 iterations XGBoost
# Mean Accuracy:  0.9125
# Std Accuracy:  0.0071
# Mean Precision:  0.9188
# Std Precision:  0.0096
# Mean Recall:  0.9686
# Std Recall:  0.0058
# Mean ROC-AUC:  0.9529
# Std ROC-AUC:  0.0070
# Mean F1-Score:  0.9422
# Std F1-Score:  0.0046

# %%
# Random Forest
accuracy_list = []
precision_list = []
recall_list = []
roc_auc_list = []
f1_score_list = []

iterations = 10

for it in range(1,iterations+1):
    print(f"Printing values for iteration {it}\n")
    df_shuffled = df.sample(frac=1) # Shuffling the DataFrame 

    # Extracting values from the shuffled DataFrame in form of NumPy array
    X1= df_shuffled.iloc[:, :-1].values
    y1 = df_shuffled.iloc[:,-1].values

    rf_classifier = RandomForestClassifier(n_estimators=100, random_state=42)
    pipeline_decision_tree = create_pipeline(rf_classifier)
    acc, precision, roc_auc, recall, f1_score = calculate_metrics(pipeline_decision_tree,X1,y1)
    accuracy_list.append(acc)
    precision_list.append(precision)
    roc_auc_list.append(roc_auc)
    recall_list.append(recall)
    f1_score_list.append(f1_score)
# Out:
# Printing values for iteration 1
#
# Printing Accuracy scores:  [0.91304348 0.95652174 0.85507246 0.89855072 0.94202899]
# Mean Accuracy:  0.91304
#
# Printing Precision scores:  [0.95744681 0.94117647 0.86440678 0.94339623 0.94444444]
# Mean Precision:  0.93017
#
# Printing ROC-AUC scores:  [0.93877551 0.96180556 0.87323113 0.94506173 0.99604072]
# Mean ROC-AUC:  0.94298
#
# Printing Recall scores:  [0.91836735 1.         0.96226415 0.92592593 0.98076923]
# Mean Recall:  0.95747
#
# Printing F1 scores:  [0.9375     0.96969697 0.91071429 0.93457944 0.96226415]
# Mean F1:  0.94295
#
# Printing values for iteration 2
#
# Printing Accuracy scores:  [0.82608696 0.94202899 0.91304348 0.88405797 0.88405797]
# Mean Accuracy:  0.88986
#
# Printing Precision scores:  [0.85964912 0.94230769 0.89795918 0.89285714 0.96153846]
# Mean Precision:  0.91086
#
# Printing ROC-AUC scores:  [0.89976415 0.98       0.97175926 0.9321267  0.94642857]
# Mean ROC-AUC:  0.94602
#
# Printing Recall scores:  [0.9245283  0.98       0.97777778 0.96153846 0.89285714]
# Mean Recall:  0.94734
#
# Printing F1 scores:  [0.89090909 0.96078431 0.93617021 0.92592593 0.92592593]
# Mean F1:  0.92794
#
# Printing values for iteration 3
#
# Printing Accuracy scores:  [0.91304348 0.94202899 0.89855072 0.91304348 0.89855072]
# Mean Accuracy:  0.91304
#
# Printing Precision scores:  [0.92307692 0.96153846 0.94117647 0.94117647 0.92307692]
# Mean Precision:  0.93801
#
# Printing ROC-AUC scores:  [0.89052632 0.96719457 0.94174208 0.95424837 0.9537037 ]
# Mean ROC-AUC:  0.94148
#
# Printing Recall scores:  [0.96       0.96153846 0.92307692 0.94117647 0.94117647]
# Mean Recall:  0.94539
#
# Printing F1 scores:  [0.94117647 0.96153846 0.93203883 0.94117647 0.93203883]
# Mean F1:  0.94159
#
# Printing values for iteration 4
#
# Printing Accuracy scores:  [0.85507246 0.92753623 0.89855072 0.89855072 0.91304348]
# Mean Accuracy:  0.89855
#
# Printing Precision scores:  [0.86792453 0.94117647 0.9787234  0.94339623 0.89473684]
# Mean Precision:  0.92519
#
# Printing ROC-AUC scores:  [0.91938776 0.97105263 0.95984163 0.93888889 0.96023965]
# Mean ROC-AUC:  0.94988
#
# Printing Recall scores:  [0.93877551 0.96       0.88461538 0.92592593 1.        ]
# Mean Recall:  0.94186
#
# Printing F1 scores:  [0.90196078 0.95049505 0.92929293 0.93457944 0.94444444]
# Mean F1:  0.93215
#
# Printing values for iteration 5
#
# Printing Accuracy scores:  [0.85507246 0.92753623 0.95652174 0.91304348 0.88405797]
# Mean Accuracy:  0.90725
#
# Printing Precision scores:  [0.85454545 0.96078431 0.96296296 0.9245283  0.92156863]
# Mean Precision:  0.92488
#
# Printing ROC-AUC scores:  [0.91020408 0.97680995 0.98290094 0.97222222 0.93082789]
# Mean ROC-AUC:  0.95459
#
# Printing Recall scores:  [0.95918367 0.94230769 0.98113208 0.96078431 0.92156863]
# Mean Recall:  0.953
#
# Printing F1 scores:  [0.90384615 0.95145631 0.97196262 0.94230769 0.92156863]
# Mean F1:  0.93823
#
# Printing values for iteration 6
#
# Printing Accuracy scores:  [0.88405797 0.88405797 0.89855072 0.92753623 0.92753623]
# Mean Accuracy:  0.90435
#
# Printing Precision scores:  [0.87719298 0.91836735 0.89285714 0.93617021 0.98214286]
# Mean Precision:  0.92135
#
# Printing ROC-AUC scores:  [0.94607843 0.94030612 0.95152505 0.96928166 0.96016949]
# Mean ROC-AUC:  0.95347
#
# Printing Recall scores:  [0.98039216 0.91836735 0.98039216 0.95652174 0.93220339]
# Mean Recall:  0.95358
#
# Printing F1 scores:  [0.92592593 0.91836735 0.93457944 0.94623656 0.95652174]
# Mean F1:  0.93633
#
# Printing values for iteration 7
#
# Printing Accuracy scores:  [0.89855072 0.88405797 0.86956522 0.92753623 0.86956522]
# Mean Accuracy:  0.88986
#
# Printing Precision scores:  [0.94       0.90740741 0.85964912 0.94642857 0.89795918]
# Mean Precision:  0.91029
#
# Printing ROC-AUC scores:  [0.94771242 0.91233032 0.96526316 0.97662338 0.9593254 ]
# Mean ROC-AUC:  0.95225
#
# Printing Recall scores:  [0.92156863 0.94230769 0.98       0.96363636 0.91666667]
# Mean Recall:  0.94484
#
# Printing F1 scores:  [0.93069307 0.9245283  0.91588785 0.95495495 0.90721649]
# Mean F1:  0.92666
#
# Printing values for iteration 8
#
# Printing Accuracy scores:  [0.92753623 0.85507246 0.91304348 0.89855072 0.91304348]
# Mean Accuracy:  0.90145
#
# Printing Precision scores:  [0.92156863 0.91111111 0.98148148 0.89090909 0.92727273]
# Mean Precision:  0.92647
#
# Printing ROC-AUC scores:  [0.95337302 0.95938104 0.97648903 0.92947368 0.93455189]
# Mean ROC-AUC:  0.95065
#
# Printing Recall scores:  [0.97916667 0.87234043 0.9137931  0.98       0.96226415]
# Mean Recall:  0.94151
#
# Printing F1 scores:  [0.94949495 0.89130435 0.94642857 0.93333333 0.94444444]
# Mean F1:  0.933
#
# Printing values for iteration 9
#
# Printing Accuracy scores:  [0.89855072 0.94202899 0.92753623 0.85507246 0.82608696]
# Mean Accuracy:  0.88986
#
# Printing Precision scores:  [0.9245283  0.98       0.96296296 0.87037037 0.84313725]
# Mean Precision:  0.9162
#
# Printing ROC-AUC scores:  [0.96153846 0.99264706 0.94675325 0.93894737 0.90764023]
# Mean ROC-AUC:  0.94951
#
# Printing Recall scores:  [0.94230769 0.94230769 0.94545455 0.94       0.91489362]
# Mean Recall:  0.93699
#
# Printing F1 scores:  [0.93333333 0.96078431 0.95412844 0.90384615 0.87755102]
# Mean F1:  0.92593
#
# Printing values for iteration 10
#
# Printing Accuracy scores:  [0.92753623 0.92753623 0.89855072 0.82608696 0.86956522]
# Mean Accuracy:  0.88986
#
# Printing Precision scores:  [0.92307692 0.96153846 0.96078431 0.83928571 0.88679245]
# Mean Precision:  0.9143
#
# Printing ROC-AUC scores:  [0.975      0.97287736 0.93271605 0.95       0.88421053]
# Mean ROC-AUC:  0.94296
#
# Printing Recall scores:  [0.97959184 0.94339623 0.90740741 0.94       0.94      ]
# Mean Recall:  0.94208
#
# Printing F1 scores:  [0.95049505 0.95238095 0.93333333 0.88679245 0.91262136]
# Mean F1:  0.92712

# %%
print("Printing values for 10 iterations Random Forest")
# Calculate the mean and std accuracy
mean_accuracy = sum(accuracy_list) / len(accuracy_list)
std_accuracy = np.std(accuracy_list)

# Report the mean accuracy up to 4 decimal points
print(f"Mean Accuracy: {mean_accuracy : .4f}")
print(f"Std Accuracy: {std_accuracy : .4f}")

# Calculate the mean and std precision
mean_precision = sum(precision_list) / len(precision_list)
std_precision = np.std(precision_list)
# Report the mean precision up to 4 decimal points

print(f"Mean Precision: {mean_precision : .4f}")
print(f"Std Precision: {std_precision : .4f}")

# Calculate the mean and std recall
mean_recall = sum(recall_list) / len(recall_list)
std_recall = np.std(recall_list)
# Report the mean recall up to 4 decimal points

print(f"Mean Recall: {mean_recall : .4f}")
print(f"Std Recall: {std_recall : .4f}")

# Calculate the mean and std roc_auc
mean_roc_auc = sum(roc_auc_list) / len(roc_auc_list)
std_roc_auc = np.std(roc_auc_list)
# Report the mean roc_auc up to 4 decimal points

print(f"Mean ROC-AUC: {mean_roc_auc : .4f}")
print(f"Std ROC-AUC: {std_roc_auc : .4f}")

# Calculate the mean and std f1_score
mean_f1_score = sum(f1_score_list) / len(f1_score_list)
std_f1_score = np.std(f1_score_list)
# Report the mean f1-score up to 4 decimal points

print(f"Mean F1-Score: {mean_f1_score : .4f}")
print(f"Std F1-Score: {std_f1_score : .4f}")
# Out:
# Printing values for 10 iterations Random Forest
# Mean Accuracy:  0.8997
# Std Accuracy:  0.0091
# Mean Precision:  0.9218
# Std Precision:  0.0085
# Mean Recall:  0.9464
# Std Recall:  0.0061
# Mean ROC-AUC:  0.9484
# Std ROC-AUC:  0.0045
# Mean F1-Score:  0.9332
# Std F1-Score:  0.0060

# %%
# SVC
accuracy_list = []
precision_list = []
recall_list = []
roc_auc_list = []
f1_score_list = []

iterations = 10

for it in range(1,iterations+1):
    print(f"Printing values for iteration {it}\n")
    df_shuffled = df.sample(frac=1) # Shuffling the DataFrame 

    # Extracting values from the shuffled DataFrame in form of NumPy array
    X1= df_shuffled.iloc[:, :-1].values
    y1 = df_shuffled.iloc[:,-1].values

    svc_classifier = SVC(kernel='rbf', C=1.0, gamma='scale')
    pipeline_decision_tree = create_pipeline(svc_classifier)
    acc, precision, roc_auc, recall, f1_score = calculate_metrics(pipeline_decision_tree,X1,y1)
    accuracy_list.append(acc)
    precision_list.append(precision)
    roc_auc_list.append(roc_auc)
    recall_list.append(recall)
    f1_score_list.append(f1_score)
# Out:
# Printing values for iteration 1
#
# Printing Accuracy scores:  [0.91304348 0.88405797 0.91304348 0.86956522 0.85507246]
# Mean Accuracy:  0.88696
#
# Printing Precision scores:  [0.96428571 0.88888889 0.92727273 0.86792453 0.8627451 ]
# Mean Precision:  0.90222
#
# Printing ROC-AUC scores:  [0.90125392 0.93473684 0.94929245 0.93452381 0.95261122]
# Mean ROC-AUC:  0.93448
#
# Printing Recall scores:  [0.93103448 0.96       0.96226415 0.95833333 0.93617021]
# Mean Recall:  0.94956
#
# Printing F1 scores:  [0.94736842 0.92307692 0.94444444 0.91089109 0.89795918]
# Mean F1:  0.92475
#
# Printing values for iteration 2
#
# Printing Accuracy scores:  [0.86956522 0.85507246 0.85507246 0.89855072 0.85507246]
# Mean Accuracy:  0.86667
#
# Printing Precision scores:  [0.92592593 0.89655172 0.83333333 0.90196078 0.88679245]
# Mean Precision:  0.88891
#
# Printing ROC-AUC scores:  [0.94285714 0.87637363 0.9489603  0.96130952 0.92701525]
# Mean ROC-AUC:  0.9313
#
# Printing Recall scores:  [0.90909091 0.92857143 0.97826087 0.95833333 0.92156863]
# Mean Recall:  0.93917
#
# Printing F1 scores:  [0.91743119 0.9122807  0.9        0.92929293 0.90384615]
# Mean F1:  0.91257
#
# Printing values for iteration 3
#
# Printing Accuracy scores:  [0.94202899 0.82608696 0.82608696 0.88405797 0.91304348]
# Mean Accuracy:  0.87826
#
# Printing Precision scores:  [0.94117647 0.89090909 0.84615385 0.87272727 0.92982456]
# Mean Precision:  0.89616
#
# Printing ROC-AUC scores:  [0.97244898 0.91818182 0.86706349 0.96122449 0.95324675]
# Mean ROC-AUC:  0.93443
#
# Printing Recall scores:  [0.97959184 0.89090909 0.91666667 0.97959184 0.96363636]
# Mean Recall:  0.94608
#
# Printing F1 scores:  [0.96       0.89090909 0.88       0.92307692 0.94642857]
# Mean F1:  0.92008
#
# Printing values for iteration 4
#
# Printing Accuracy scores:  [0.82608696 0.91304348 0.85507246 0.88405797 0.89855072]
# Mean Accuracy:  0.87536
#
# Printing Precision scores:  [0.87037037 0.90566038 0.88888889 0.90566038 0.89473684]
# Mean Precision:  0.89306
#
# Printing ROC-AUC scores:  [0.88687783 0.98367347 0.91742081 0.91285403 0.95588235]
# Mean ROC-AUC:  0.93134
#
# Printing Recall scores:  [0.90384615 0.97959184 0.92307692 0.94117647 0.98076923]
# Mean Recall:  0.94569
#
# Printing F1 scores:  [0.88679245 0.94117647 0.90566038 0.92307692 0.93577982]
# Mean F1:  0.9185
#
# Printing values for iteration 5
#
# Printing Accuracy scores:  [0.92753623 0.89855072 0.84057971 0.89855072 0.84057971]
# Mean Accuracy:  0.88116
#
# Printing Precision scores:  [0.94545455 0.88235294 0.87931034 0.92592593 0.83636364]
# Mean Precision:  0.89388
#
# Printing ROC-AUC scores:  [0.95925926 0.95274102 0.89480519 0.96462264 0.94543651]
# Mean ROC-AUC:  0.94337
#
# Printing Recall scores:  [0.96296296 0.97826087 0.92727273 0.94339623 0.95833333]
# Mean Recall:  0.95405
#
# Printing F1 scores:  [0.95412844 0.92783505 0.90265487 0.93457944 0.89320388]
# Mean F1:  0.92248
#
# Printing values for iteration 6
#
# Printing Accuracy scores:  [0.85507246 0.92753623 0.85507246 0.84057971 0.82608696]
# Mean Accuracy:  0.86087
#
# Printing Precision scores:  [0.90566038 0.96363636 0.87272727 0.84       0.84210526]
# Mean Precision:  0.88483
#
# Printing ROC-AUC scores:  [0.94339623 0.96840659 0.90305011 0.93981481 0.93572985]
# Mean ROC-AUC:  0.93808
#
# Printing Recall scores:  [0.90566038 0.94642857 0.94117647 0.93333333 0.94117647]
# Mean Recall:  0.93356
#
# Printing F1 scores:  [0.90566038 0.95495495 0.90566038 0.88421053 0.88888889]
# Mean F1:  0.90788
#
# Printing values for iteration 7
#
# Printing Accuracy scores:  [0.85507246 0.85507246 0.8115942  0.89855072 0.89855072]
# Mean Accuracy:  0.86377
#
# Printing Precision scores:  [0.92592593 0.88235294 0.81481481 0.94736842 0.86792453]
# Mean Precision:  0.88768
#
# Printing ROC-AUC scores:  [0.93681319 0.9244898  0.84912959 0.95454545 0.98298677]
# Mean ROC-AUC:  0.92959
#
# Printing Recall scores:  [0.89285714 0.91836735 0.93617021 0.93103448 1.        ]
# Mean Recall:  0.93569
#
# Printing F1 scores:  [0.90909091 0.9        0.87128713 0.93913043 0.92929293]
# Mean F1:  0.90976
#
# Printing values for iteration 8
#
# Printing Accuracy scores:  [0.84057971 0.88405797 0.85507246 0.85507246 0.91304348]
# Mean Accuracy:  0.86957
#
# Printing Precision scores:  [0.89090909 0.87272727 0.91071429 0.8627451  0.92307692]
# Mean Precision:  0.89203
#
# Printing ROC-AUC scores:  [0.86296296 0.9744898  0.92032967 0.95357834 0.97052632]
# Mean ROC-AUC:  0.93638
#
# Printing Recall scores:  [0.90740741 0.97959184 0.91071429 0.93617021 0.96      ]
# Mean Recall:  0.93878
#
# Printing F1 scores:  [0.89908257 0.92307692 0.91071429 0.89795918 0.94117647]
# Mean F1:  0.9144
#
# Printing values for iteration 9
#
# Printing Accuracy scores:  [0.86956522 0.88405797 0.91304348 0.92753623 0.8115942 ]
# Mean Accuracy:  0.88116
#
# Printing Precision scores:  [0.85454545 0.88461538 0.89655172 0.98113208 0.85454545]
# Mean Precision:  0.89428
#
# Printing ROC-AUC scores:  [0.96031746 0.92857143 0.94343891 0.96016484 0.88122172]
# Mean ROC-AUC:  0.93474
#
# Printing Recall scores:  [0.97916667 0.95833333 1.         0.92857143 0.90384615]
# Mean Recall:  0.95398
#
# Printing F1 scores:  [0.91262136 0.92       0.94545455 0.95412844 0.87850467]
# Mean F1:  0.92214
#
# Printing values for iteration 10
#
# Printing Accuracy scores:  [0.85507246 0.89855072 0.86956522 0.91304348 0.91304348]
# Mean Accuracy:  0.88986
#
# Printing Precision scores:  [0.86538462 0.87037037 0.90740741 0.9245283  0.98113208]
# Mean Precision:  0.90976
#
# Printing ROC-AUC scores:  [0.94246032 0.95067698 0.90448113 0.95315904 0.96637427]
# Mean ROC-AUC:  0.94343
#
# Printing Recall scores:  [0.9375     1.         0.9245283  0.96078431 0.9122807 ]
# Mean Recall:  0.94702
#
# Printing F1 scores:  [0.9        0.93069307 0.91588785 0.94230769 0.94545455]
# Mean F1:  0.92687

# %%
print("Printing values for 10 iterations SVC")
# Calculate the mean and std accuracy
mean_accuracy = sum(accuracy_list) / len(accuracy_list)
std_accuracy = np.std(accuracy_list)

# Report the mean accuracy up to 4 decimal points
print(f"Mean Accuracy: {mean_accuracy : .4f}")
print(f"Std Accuracy: {std_accuracy : .4f}")

# Calculate the mean and std precision
mean_precision = sum(precision_list) / len(precision_list)
std_precision = np.std(precision_list)
# Report the mean precision up to 4 decimal points

print(f"Mean Precision: {mean_precision : .4f}")
print(f"Std Precision: {std_precision : .4f}")

# Calculate the mean and std recall
mean_recall = sum(recall_list) / len(recall_list)
std_recall = np.std(recall_list)
# Report the mean recall up to 4 decimal points

print(f"Mean Recall: {mean_recall : .4f}")
print(f"Std Recall: {std_recall : .4f}")

# Calculate the mean and std roc_auc
mean_roc_auc = sum(roc_auc_list) / len(roc_auc_list)
std_roc_auc = np.std(roc_auc_list)
# Report the mean roc_auc up to 4 decimal points

print(f"Mean ROC-AUC: {mean_roc_auc : .4f}")
print(f"Std ROC-AUC: {std_roc_auc : .4f}")

# Calculate the mean and std f1_score
mean_f1_score = sum(f1_score_list) / len(f1_score_list)
std_f1_score = np.std(f1_score_list)
# Report the mean f1-score up to 4 decimal points

print(f"Mean F1-Score: {mean_f1_score : .4f}")
print(f"Std F1-Score: {std_f1_score : .4f}")
# Out:
# Printing values for 10 iterations SVC
# Mean Accuracy:  0.8754
# Std Accuracy:  0.0093
# Mean Precision:  0.8943
# Std Precision:  0.0069
# Mean Recall:  0.9444
# Std Recall:  0.0069
# Mean ROC-AUC:  0.9357
# Std ROC-AUC:  0.0045
# Mean F1-Score:  0.9179
# Std F1-Score:  0.0062

# %%
# KNN
accuracy_list = []
precision_list = []
recall_list = []
roc_auc_list = []
f1_score_list = []

iterations = 10

for it in range(1,iterations+1):
    print(f"Printing values for iteration {it}\n")
    df_shuffled = df.sample(frac=1) # Shuffling the DataFrame 

    # Extracting values from the shuffled DataFrame in form of NumPy array
    X1= df_shuffled.iloc[:, :-1].values
    y1 = df_shuffled.iloc[:,-1].values

    knn = KNeighborsClassifier(n_neighbors=6)
    pipeline_decision_tree = create_pipeline(knn)
    acc, precision, roc_auc, recall, f1_score = calculate_metrics(pipeline_decision_tree,X1,y1)
    accuracy_list.append(acc)
    precision_list.append(precision)
    roc_auc_list.append(roc_auc)
    recall_list.append(recall)
    f1_score_list.append(f1_score)
# Out:
# Printing values for iteration 1
#
# Printing Accuracy scores:  [0.89855072 0.84057971 0.82608696 0.91304348 0.8115942 ]
# Mean Accuracy:  0.85797
#
# Printing Precision scores:  [0.92307692 0.86       0.94       1.         0.86792453]
# Mean Precision:  0.9182
#
# Printing ROC-AUC scores:  [0.97276688 0.92359768 0.9010989  0.94368421 0.83766968]
# Mean ROC-AUC:  0.91576
#
# Printing Recall scores:  [0.94117647 0.91489362 0.83928571 0.88       0.88461538]
# Mean Recall:  0.89199
#
# Printing F1 scores:  [0.93203883 0.88659794 0.88679245 0.93617021 0.87619048]
# Mean F1:  0.90356
#
# Printing values for iteration 2
#
# Printing Accuracy scores:  [0.85507246 0.84057971 0.79710145 0.91304348 0.88405797]
# Mean Accuracy:  0.85797
#
# Printing Precision scores:  [0.86666667 0.92307692 0.9375     0.94444444 0.9       ]
# Mean Precision:  0.91434
#
# Printing ROC-AUC scores:  [0.92844365 0.89545455 0.9010989  0.97407407 0.9280754 ]
# Mean ROC-AUC:  0.92543
#
# Printing Recall scores:  [0.90697674 0.87272727 0.80357143 0.94444444 0.9375    ]
# Mean Recall:  0.89304
#
# Printing F1 scores:  [0.88636364 0.89719626 0.86538462 0.94444444 0.91836735]
# Mean F1:  0.90235
#
# Printing values for iteration 3
#
# Printing Accuracy scores:  [0.85507246 0.89855072 0.8115942  0.84057971 0.89855072]
# Mean Accuracy:  0.86087
#
# Printing Precision scores:  [0.93877551 0.94       0.85416667 0.89795918 0.96153846]
# Mean Precision:  0.91849
#
# Printing ROC-AUC scores:  [0.89917453 0.91448802 0.90909091 0.91789474 0.92272727]
# Mean ROC-AUC:  0.91268
#
# Printing Recall scores:  [0.86792453 0.92156863 0.87234043 0.88       0.90909091]
# Mean Recall:  0.89018
#
# Printing F1 scores:  [0.90196078 0.93069307 0.86315789 0.88888889 0.93457944]
# Mean F1:  0.90386
#
# Printing values for iteration 4
#
# Printing Accuracy scores:  [0.89855072 0.89855072 0.76811594 0.91304348 0.85507246]
# Mean Accuracy:  0.86667
#
# Printing Precision scores:  [0.94117647 0.92307692 0.94736842 0.98076923 0.87755102]
# Mean Precision:  0.93399
#
# Printing ROC-AUC scores:  [0.92929864 0.93845316 0.93210526 0.96016484 0.90909091]
# Mean ROC-AUC:  0.93382
#
# Printing Recall scores:  [0.92307692 0.94117647 0.72       0.91071429 0.91489362]
# Mean Recall:  0.88197
#
# Printing F1 scores:  [0.93203883 0.93203883 0.81818182 0.94444444 0.89583333]
# Mean F1:  0.90451
#
# Printing values for iteration 5
#
# Printing Accuracy scores:  [0.89855072 0.76811594 0.88405797 0.94202899 0.89855072]
# Mean Accuracy:  0.87826
#
# Printing Precision scores:  [0.92       0.89130435 0.93877551 0.98       0.94117647]
# Mean Precision:  0.93425
#
# Printing ROC-AUC scores:  [0.95714286 0.85746606 0.90958606 0.95418552 0.93608597]
# Mean ROC-AUC:  0.92289
#
# Printing Recall scores:  [0.93877551 0.78846154 0.90196078 0.94230769 0.92307692]
# Mean Recall:  0.89892
#
# Printing F1 scores:  [0.92929293 0.83673469 0.92       0.96078431 0.93203883]
# Mean F1:  0.91577
#
# Printing values for iteration 6
#
# Printing Accuracy scores:  [0.7826087  0.85507246 0.86956522 0.91304348 0.95652174]
# Mean Accuracy:  0.87536
#
# Printing Precision scores:  [0.95238095 0.85416667 0.93877551 0.94230769 0.96428571]
# Mean Precision:  0.93038
#
# Printing ROC-AUC scores:  [0.89445755 0.94818182 0.88178733 0.91346154 0.96168831]
# Mean ROC-AUC:  0.91992
#
# Printing Recall scores:  [0.75471698 0.93181818 0.88461538 0.94230769 0.98181818]
# Mean Recall:  0.89906
#
# Printing F1 scores:  [0.84210526 0.89130435 0.91089109 0.94230769 0.97297297]
# Mean F1:  0.91192
#
# Printing values for iteration 7
#
# Printing Accuracy scores:  [0.86956522 0.88405797 0.88405797 0.86956522 0.86956522]
# Mean Accuracy:  0.87536
#
# Printing Precision scores:  [0.91489362 0.93478261 0.9787234  0.94230769 0.97777778]
# Mean Precision:  0.9497
#
# Printing ROC-AUC scores:  [0.92261905 0.93204365 0.94752358 0.88766234 0.93042986]
# Mean ROC-AUC:  0.92406
#
# Printing Recall scores:  [0.89583333 0.89583333 0.86792453 0.89090909 0.84615385]
# Mean Recall:  0.87933
#
# Printing F1 scores:  [0.90526316 0.91489362 0.92       0.91588785 0.90721649]
# Mean F1:  0.91265
#
# Printing values for iteration 8
#
# Printing Accuracy scores:  [0.91304348 0.84057971 0.82608696 0.92753623 0.88405797]
# Mean Accuracy:  0.87826
#
# Printing Precision scores:  [0.9787234  0.89361702 0.97619048 0.96078431 0.9245283 ]
# Mean Precision:  0.94677
#
# Printing ROC-AUC scores:  [0.95915033 0.90823413 0.85180995 0.97850679 0.91863208]
# Mean ROC-AUC:  0.92327
#
# Printing Recall scores:  [0.90196078 0.875      0.78846154 0.94230769 0.9245283 ]
# Mean Recall:  0.88645
#
# Printing F1 scores:  [0.93877551 0.88421053 0.87234043 0.95145631 0.9245283 ]
# Mean F1:  0.91426
#
# Printing values for iteration 9
#
# Printing Accuracy scores:  [0.7826087  0.85507246 0.85507246 0.94202899 0.88405797]
# Mean Accuracy:  0.86377
#
# Printing Precision scores:  [0.89130435 0.90384615 0.95238095 0.98039216 0.92307692]
# Mean Precision:  0.9302
#
# Printing ROC-AUC scores:  [0.87908497 0.8800905  0.95734127 0.96403302 0.87782805]
# Mean ROC-AUC:  0.91168
#
# Printing Recall scores:  [0.80392157 0.90384615 0.83333333 0.94339623 0.92307692]
# Mean Recall:  0.88151
#
# Printing F1 scores:  [0.84536082 0.90384615 0.88888889 0.96153846 0.92307692]
# Mean F1:  0.90454
#
# Printing values for iteration 10
#
# Printing Accuracy scores:  [0.84057971 0.94202899 0.88405797 0.88405797 0.79710145]
# Mean Accuracy:  0.86957
#
# Printing Precision scores:  [0.93181818 1.         0.9        0.94       0.89583333]
# Mean Precision:  0.93353
#
# Printing ROC-AUC scores:  [0.89030612 0.97012987 0.91121032 0.93947964 0.90667421]
# Mean ROC-AUC:  0.92356
#
# Printing Recall scores:  [0.83673469 0.92727273 0.9375     0.90384615 0.82692308]
# Mean Recall:  0.88646
#
# Printing F1 scores:  [0.88172043 0.96226415 0.91836735 0.92156863 0.86      ]
# Mean F1:  0.90878

# %%
print("Printing values for 10 iterations KNN")
# Calculate the mean and std accuracy
mean_accuracy = sum(accuracy_list) / len(accuracy_list)
std_accuracy = np.std(accuracy_list)

# Report the mean accuracy up to 4 decimal points
print(f"Mean Accuracy: {mean_accuracy : .4f}")
print(f"Std Accuracy: {std_accuracy : .4f}")

# Calculate the mean and std precision
mean_precision = sum(precision_list) / len(precision_list)
std_precision = np.std(precision_list)
# Report the mean precision up to 4 decimal points

print(f"Mean Precision: {mean_precision : .4f}")
print(f"Std Precision: {std_precision : .4f}")

# Calculate the mean and std recall
mean_recall = sum(recall_list) / len(recall_list)
std_recall = np.std(recall_list)
# Report the mean recall up to 4 decimal points

print(f"Mean Recall: {mean_recall : .4f}")
print(f"Std Recall: {std_recall : .4f}")

# Calculate the mean and std roc_auc
mean_roc_auc = sum(roc_auc_list) / len(roc_auc_list)
std_roc_auc = np.std(roc_auc_list)
# Report the mean roc_auc up to 4 decimal points

print(f"Mean ROC-AUC: {mean_roc_auc : .4f}")
print(f"Std ROC-AUC: {std_roc_auc : .4f}")

# Calculate the mean and std f1_score
mean_f1_score = sum(f1_score_list) / len(f1_score_list)
std_f1_score = np.std(f1_score_list)
# Report the mean f1-score up to 4 decimal points

print(f"Mean F1-Score: {mean_f1_score : .4f}")
print(f"Std F1-Score: {std_f1_score : .4f}")
# Out:
# Printing values for 10 iterations KNN
# Mean Accuracy:  0.8684
# Std Accuracy:  0.0077
# Mean Precision:  0.9310
# Std Precision:  0.0111
# Mean Recall:  0.8889
# Std Recall:  0.0066
# Mean ROC-AUC:  0.9213
# Std ROC-AUC:  0.0063
# Mean F1-Score:  0.9082
# Std F1-Score:  0.0048

# %%
# Naives Bayes
accuracy_list = []
precision_list = []
recall_list = []
roc_auc_list = []
f1_score_list = []

iterations = 10

for it in range(1,iterations+1):
    print(f"Printing values for iteration {it}\n")
    df_shuffled = df.sample(frac=1) # Shuffling the DataFrame 

    # Extracting values from the shuffled DataFrame in form of NumPy array
    X1= df_shuffled.iloc[:, :-1].values
    y1 = df_shuffled.iloc[:,-1].values

    naive_bayes = GaussianNB()
    pipeline_decision_tree = create_pipeline(naive_bayes)
    acc, precision, roc_auc, recall, f1_score = calculate_metrics(pipeline_decision_tree,X1,y1)
    accuracy_list.append(acc)
    precision_list.append(precision)
    roc_auc_list.append(roc_auc)
    recall_list.append(recall)
    f1_score_list.append(f1_score)
# Out:
# Printing values for iteration 1
#
# Printing Accuracy scores:  [0.69565217 0.71014493 0.71014493 0.65217391 0.71014493]
# Mean Accuracy:  0.69565
#
# Printing Precision scores:  [0.95652174 0.97297297 0.91891892 0.96666667 0.95      ]
# Mean Precision:  0.95302
#
# Printing ROC-AUC scores:  [0.90035273 0.88246753 0.80010893 0.8178733  0.82211538]
# Mean ROC-AUC:  0.84458
#
# Printing Recall scores:  [0.52380952 0.65454545 0.66666667 0.55769231 0.67857143]
# Mean Recall:  0.61626
#
# Printing F1 scores:  [0.67692308 0.7826087  0.77272727 0.70731707 0.79166667]
# Mean F1:  0.74625
#
# Printing values for iteration 2
#
# Printing Accuracy scores:  [0.68115942 0.79710145 0.62318841 0.72463768 0.62318841]
# Mean Accuracy:  0.68986
#
# Printing Precision scores:  [0.875      0.97368421 0.96774194 0.94736842 1.        ]
# Mean Precision:  0.95276
#
# Printing ROC-AUC scores:  [0.81143667 0.91105263 0.89220779 0.87087264 0.80882353]
# Mean ROC-AUC:  0.85888
#
# Printing Recall scores:  [0.60869565 0.74       0.54545455 0.67924528 0.5       ]
# Mean Recall:  0.61468
#
# Printing F1 scores:  [0.71794872 0.84090909 0.69767442 0.79120879 0.66666667]
# Mean F1:  0.74288
#
# Printing values for iteration 3
#
# Printing Accuracy scores:  [0.69565217 0.72463768 0.62318841 0.72463768 0.65217391]
# Mean Accuracy:  0.68406
#
# Printing Precision scores:  [0.9375     0.90909091 1.         0.97368421 0.94117647]
# Mean Precision:  0.95229
#
# Printing ROC-AUC scores:  [0.85357143 0.84499055 0.91289593 0.83506494 0.85925926]
# Mean ROC-AUC:  0.86116
#
# Printing Recall scores:  [0.6122449  0.65217391 0.5        0.67272727 0.59259259]
# Mean Recall:  0.60595
#
# Printing F1 scores:  [0.74074074 0.75949367 0.66666667 0.79569892 0.72727273]
# Mean F1:  0.73797
#
# Printing values for iteration 4
#
# Printing Accuracy scores:  [0.55072464 0.68115942 0.73913043 0.8115942  0.8115942 ]
# Mean Accuracy:  0.71884
#
# Printing Precision scores:  [0.93103448 0.96774194 0.90625    0.95121951 1.        ]
# Mean Precision:  0.95125
#
# Printing ROC-AUC scores:  [0.77335165 0.89106754 0.83590909 0.89473684 0.89220779]
# Mean ROC-AUC:  0.85745
#
# Printing Recall scores:  [0.48214286 0.58823529 0.65909091 0.78       0.76363636]
# Mean Recall:  0.65462
#
# Printing F1 scores:  [0.63529412 0.73170732 0.76315789 0.85714286 0.86597938]
# Mean F1:  0.77066
#
# Printing values for iteration 5
#
# Printing Accuracy scores:  [0.73913043 0.69565217 0.62318841 0.75362319 0.73913043]
# Mean Accuracy:  0.71014
#
# Printing Precision scores:  [1.         0.9375     0.87878788 0.95348837 1.        ]
# Mean Precision:  0.95396
#
# Printing ROC-AUC scores:  [0.87003968 0.84591837 0.7788671  0.86675824 0.93325792]
# Mean ROC-AUC:  0.85897
#
# Printing Recall scores:  [0.625      0.6122449  0.56862745 0.73214286 0.65384615]
# Mean Recall:  0.63837
#
# Printing F1 scores:  [0.76923077 0.74074074 0.69047619 0.82828283 0.79069767]
# Mean F1:  0.76389
#
# Printing values for iteration 6
#
# Printing Accuracy scores:  [0.75362319 0.72463768 0.69565217 0.69565217 0.65217391]
# Mean Accuracy:  0.70435
#
# Printing Precision scores:  [0.92307692 1.         1.         0.875      0.91176471]
# Mean Precision:  0.94197
#
# Printing ROC-AUC scores:  [0.80947368 0.91037736 0.88598901 0.82592593 0.7918552 ]
# Mean ROC-AUC:  0.84472
#
# Printing Recall scores:  [0.72       0.64150943 0.625      0.62222222 0.59615385]
# Mean Recall:  0.64098
#
# Printing F1 scores:  [0.80898876 0.7816092  0.76923077 0.72727273 0.72093023]
# Mean F1:  0.76161
#
# Printing values for iteration 7
#
# Printing Accuracy scores:  [0.72463768 0.8115942  0.63768116 0.72463768 0.63768116]
# Mean Accuracy:  0.70725
#
# Printing Precision scores:  [0.84848485 1.         0.92592593 0.97297297 0.97058824]
# Mean Precision:  0.94359
#
# Printing ROC-AUC scores:  [0.80599647 0.8961039  0.87202381 0.90493827 0.83991228]
# Mean ROC-AUC:  0.86379
#
# Printing Recall scores:  [0.66666667 0.76363636 0.52083333 0.66666667 0.57894737]
# Mean Recall:  0.63935
#
# Printing F1 scores:  [0.74666667 0.86597938 0.66666667 0.79120879 0.72527473]
# Mean F1:  0.75916
#
# Printing values for iteration 8
#
# Printing Accuracy scores:  [0.63768116 0.68115942 0.66666667 0.68115942 0.8115942 ]
# Mean Accuracy:  0.69565
#
# Printing Precision scores:  [0.97058824 0.93939394 0.93333333 0.96551724 0.95121951]
# Mean Precision:  0.95201
#
# Printing ROC-AUC scores:  [0.8625731  0.86492375 0.80714286 0.9122449  0.87526316]
# Mean ROC-AUC:  0.86443
#
# Printing Recall scores:  [0.57894737 0.60784314 0.57142857 0.57142857 0.78      ]
# Mean Recall:  0.62193
#
# Printing F1 scores:  [0.72527473 0.73809524 0.70886076 0.71794872 0.85714286]
# Mean F1:  0.74946
#
# Printing values for iteration 9
#
# Printing Accuracy scores:  [0.75362319 0.65217391 0.71014493 0.69565217 0.66666667]
# Mean Accuracy:  0.69565
#
# Printing Precision scores:  [1.         0.94285714 0.96153846 0.91891892 0.97058824]
# Mean Precision:  0.95878
#
# Printing ROC-AUC scores:  [0.92315789 0.72467532 0.89727273 0.85463801 0.87857143]
# Mean ROC-AUC:  0.85566
#
# Printing Recall scores:  [0.66       0.6        0.56818182 0.65384615 0.6       ]
# Mean Recall:  0.61641
#
# Printing F1 scores:  [0.79518072 0.73333333 0.71428571 0.76404494 0.74157303]
# Mean F1:  0.74968
#
# Printing values for iteration 10
#
# Printing Accuracy scores:  [0.71014493 0.65217391 0.66666667 0.73913043 0.69565217]
# Mean Accuracy:  0.69275
#
# Printing Precision scores:  [0.90625    1.         0.91666667 0.92307692 0.96774194]
# Mean Precision:  0.94275
#
# Printing ROC-AUC scores:  [0.84688091 0.84340659 0.80129717 0.83061002 0.87526316]
# Mean ROC-AUC:  0.83949
#
# Printing Recall scores:  [0.63043478 0.57142857 0.62264151 0.70588235 0.6       ]
# Mean Recall:  0.62608
#
# Printing F1 scores:  [0.74358974 0.72727273 0.74157303 0.8        0.74074074]
# Mean F1:  0.75064

# %%
print("Printing values for 10 iterations Naive Bayes")
# Calculate the mean and std accuracy
mean_accuracy = sum(accuracy_list) / len(accuracy_list)
std_accuracy = np.std(accuracy_list)

# Report the mean accuracy up to 4 decimal points
print(f"Mean Accuracy: {mean_accuracy : .4f}")
print(f"Std Accuracy: {std_accuracy : .4f}")

# Calculate the mean and std precision
mean_precision = sum(precision_list) / len(precision_list)
std_precision = np.std(precision_list)
# Report the mean precision up to 4 decimal points

print(f"Mean Precision: {mean_precision : .4f}")
print(f"Std Precision: {std_precision : .4f}")

# Calculate the mean and std recall
mean_recall = sum(recall_list) / len(recall_list)
std_recall = np.std(recall_list)
# Report the mean recall up to 4 decimal points

print(f"Mean Recall: {mean_recall : .4f}")
print(f"Std Recall: {std_recall : .4f}")

# Calculate the mean and std roc_auc
mean_roc_auc = sum(roc_auc_list) / len(roc_auc_list)
std_roc_auc = np.std(roc_auc_list)
# Report the mean roc_auc up to 4 decimal points

print(f"Mean ROC-AUC: {mean_roc_auc : .4f}")
print(f"Std ROC-AUC: {std_roc_auc : .4f}")

# Calculate the mean and std f1_score
mean_f1_score = sum(f1_score_list) / len(f1_score_list)
std_f1_score = np.std(f1_score_list)
# Report the mean f1-score up to 4 decimal points

print(f"Mean F1-Score: {mean_f1_score : .4f}")
print(f"Std F1-Score: {std_f1_score : .4f}")
# Out:
# Printing values for 10 iterations Naive Bayes
# Mean Accuracy:  0.6994
# Std Accuracy:  0.0100
# Mean Precision:  0.9502
# Std Precision:  0.0053
# Mean Recall:  0.6275
# Std Recall:  0.0144
# Mean ROC-AUC:  0.8549
# Std ROC-AUC:  0.0083
# Mean F1-Score:  0.7532
# Std F1-Score:  0.0097
